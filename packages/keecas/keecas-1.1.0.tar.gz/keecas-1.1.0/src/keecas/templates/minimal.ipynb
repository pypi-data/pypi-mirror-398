# %% [markdown]
# # Keecas Calculation
#
# Quick setup for symbolic math and units-aware calculations.

# %%
# Keecas imports
from keecas import symbols, show_eqn, check, pc, u, config, wrap_column

# Global persistence
params = {}
eqn = {}

print('Keecas ready!')

# %%
# Your calculations here
