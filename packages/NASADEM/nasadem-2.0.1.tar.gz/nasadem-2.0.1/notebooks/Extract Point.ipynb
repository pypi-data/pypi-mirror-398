# %%
from rasters import Point
from NASADEM import NASADEM
# Out:
# [2025-12-19 11:11:35 INFO] You're now authenticated with NASA Earthdata Login

# %%
geometry = Point(-118, 35)
geometry
# Out:
# POINT (-118 35)

# %%
NASADEM.elevation_km(geometry=geometry)
# Out:
# [2025-12-19 11:11:38 INFO] acquiring NASADEM tile: n35w118
# [2025-12-19 11:11:40 INFO] Granules found: 1
# [2025-12-19 11:11:43 INFO]  Getting 1 granules, approx download size: 0.01 GB
# QUEUEING TASKS | :   0%|          | 0/1 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/1 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/1 [00:00<?, ?it/s]
# [2025-12-19 11:11:47 INFO] downloaded NASADEM tile: /Users/gregoryhalverson/data/NASADEM/NASADEM_HGT_N35W118.zip
# [2025-12-19 11:11:47 INFO] loading elevation: zip:///Users/gregoryhalverson/data/NASADEM/NASADEM_HGT_N35W118.zip!/n35w118.hgt
# 0.78
