# %% [markdown]
# # Launch the experiment selection

# %% [markdown]
# Are ou trying to post-treat an old tapped experiment ?
#
# Then, you should create a new date in the beamline folder. Create then a symbolic link of the RAW_DATA (cd to your new date, type ln -s <old_RAW_DATA_folder>)

# %%
from esrf_statusgui.visualization.DCT.pySetupH5 import pySetupH5
launch_gui = pySetupH5()
launch_gui.display()
