# %% [markdown]
# # 1.1 Document Ingestion Basics - Ungraph
#
# Este notebook cubre la fase **EXTRACT** del patrón ETI: cómo cargar documentos desde diferentes formatos al sistema.
#
# ## Objetivos
#
# 1. **Configurar Ungraph** - Conexión a Neo4j y configuración básica
# 2. **Cargar documentos** - Markdown, TXT, Word, PDF
# 3. **Verificar carga** - Validar que los documentos se cargaron correctamente
# 4. **Obtener recomendaciones** - Estrategias de chunking recomendadas
#
# ## Formatos Soportados
#
# - ✅ **Markdown (.md)** - Documentos estructurados
# - ✅ **Texto plano (.txt)** - Con detección automática de encoding
# - ✅ **Word (.docx)** - Documentos de Microsoft Word
# - ✅ **PDF (.pdf)** - Usando IBM Docling para mejor extracción
#
# **Referencias:**
# - [Guía de Ingesta](../../docs/guides/ingestion.md)
# - [API Pública](../../docs/api/public-api.md)

# %%
def add_src_to_path(path_folder: str):
    ''' 
    Helper function for adding the "path_folder" directory to the path.
    '''
    import sys
    from pathlib import Path

    base_path = Path().resolve()
    for parent in [base_path] + list(base_path.parents):
        candidate = parent / path_folder
        if candidate.exists():
            parent_dir = candidate.parent
            if str(parent_dir) not in sys.path:
                sys.path.insert(0, str(parent_dir))
            if str(candidate) not in sys.path:
                sys.path.append(str(candidate))
            return

# Agregar carpetas necesarias al path
add_src_to_path(path_folder="src")
add_src_to_path(path_folder="src/utils")
add_src_to_path(path_folder="src/data")

# %%
# Importar librerías necesarias
import sys
from pathlib import Path

# Importar handlers
from src.utils.handlers import find_in_project

# Importar ungraph
try:
    import ungraph
    print("✅ Ungraph importado como paquete instalado")
except ImportError:
    import src
    ungraph = src
    print("✅ Ungraph importado desde src/ (modo desarrollo)")

print(f"📦 Ungraph version: {ungraph.__version__}")
# Out:
# ✅ Ungraph importado desde src/ (modo desarrollo)
# 📦 Ungraph version: 0.1.0

# %% [markdown]
# ## Parte 1: Configuración Inicial
#
# Primero configuramos la conexión a Neo4j. Puedes usar variables de entorno o configuración programática.

# %%
# Configurar Ungraph
# Opción 1: Usar variables de entorno (recomendado)
# export NEO4J_URI="bolt://localhost:7687"
# export NEO4J_PASSWORD="tu_contraseña"

# Opción 2: Configurar programáticamente
ungraph.configure(
    neo4j_uri="bolt://localhost:7687",
    neo4j_user="neo4j",
    neo4j_password="Ungraph22",  # ⚠️ CAMBIAR: Usa tu contraseña real
    neo4j_database="neo4j",
    embedding_model="sentence-transformers/all-MiniLM-L6-v2"
)

print("✅ Configuración completada")
print("💡 Si obtienes AuthError, verifica que Neo4j esté corriendo y las credenciales sean correctas")
# Out:
# ✅ Configuración completada
# 💡 Si obtienes AuthError, verifica que Neo4j esté corriendo y las credenciales sean correctas

# %% [markdown]
# ## Parte 2: Encontrar Archivos de Datos
#
# Localicemos los archivos de ejemplo disponibles.

# %%
# Encontrar la carpeta data
data_path = find_in_project(
    target="data",
    search_type="folder",
    project_root=None
)

print(f"📁 Carpeta de datos: {data_path}")

# Listar archivos disponibles
files = list(data_path.glob("*"))
print(f"\n📄 Archivos disponibles:")
for file in files:
    if file.is_file():
        size_kb = file.stat().st_size / 1024
        print(f"  - {file.name} ({size_kb:.1f} KB)")
# Out:
# 📁 Carpeta de datos: D:\projects\Ungraph\src\data
#
# 📄 Archivos disponibles:
#   - 110225.md (6.6 KB)
#   - AnnyLetter.txt (17.8 KB)
#   - peach-et-al-2014-qsar-modeling-of-imbalanced-high-throughput-screening-data-in-pubchem.pdf (447.4 KB)
#   - Usar símboles de silencio de corchea.docx (25.2 KB)

# %% [markdown]
# ## Parte 3: Ingerir Documentos por Formato
#
# Ahora ingerimos documentos de diferentes formatos. Cada formato tiene sus características específicas.

# %% [markdown]
# ### 3.1 Ingerir Markdown (.md)

# %%
# Ingerir archivo Markdown
markdown_file = data_path / "110225.md"

if markdown_file.exists():
    print(f"📥 Ingiriendo: {markdown_file.name}")
    chunks = ungraph.ingest_document(
        markdown_file,
        chunk_size=1000,
        chunk_overlap=200,
        clean_text=True
    )
    print(f"✅ Documento ingerido exitosamente!")
    print(f"   Total de chunks: {len(chunks)}")
    print(f"   Chunks con embeddings: {sum(1 for c in chunks if c.embeddings)}")
    
    # Mostrar información de algunos chunks
    print(f"\n📄 Primeros 2 chunks:")
    for i, chunk in enumerate(chunks[:2], 1):
        print(f"\n   Chunk {i}:")
        print(f"   - ID: {chunk.id[:50]}...")
        print(f"   - Contenido: {chunk.page_content[:100]}...")
        print(f"   - Consecutivo: {chunk.chunk_id_consecutive}")
        if chunk.embeddings:
            print(f"   - Embeddings: {len(chunk.embeddings)} dimensiones")
else:
    print(f"⚠️  Archivo no encontrado: {markdown_file}")
# Out:
# 📥 Ingiriendo: 110225.md
# 2025-12-25 21:08:41,935 - INFO - CUDA no disponible, usando CPU para embeddings.
# 2025-12-25 21:08:41,940 - INFO - Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# 2025-12-25 21:08:45,273 - INFO - Embedding service initialized with model: sentence-transformers/all-MiniLM-L6-v2
# 2025-12-25 21:08:45,274 - INFO - Loading spaCy model: en_core_web_sm
# 2025-12-25 21:08:46,329 - INFO - spaCy model loaded successfully
# 2025-12-25 21:08:46,330 - INFO - Starting document ingestion: D:\projects\Ungraph\src\data\110225.md
# 2025-12-25 21:08:46,335 - INFO - Using pattern: FILE_PAGE_CHUNK
# 2025-12-25 21:08:46,336 - INFO - Step 1: Loading document
# 2025-12-25 21:08:46,337 - INFO - Cargando archivo Markdown: D:\projects\Ungraph\src\data\110225.md
# 2025-12-25 21:08:51,304 - INFO - Starting text cleaning.
# 2025-12-25 21:08:51,305 - INFO - Text cleaning completed.
# 2025-12-25 21:08:51,306 - INFO - Archivo cargado exitosamente. Documentos generados: 1
# 2025-12-25 21:08:51,306 - INFO - Step 2: Chunking document
# 2025-12-25 21:08:51,307 - INFO - Chunking document: 110225.md
# 2025-12-25 21:08:51,308 - INFO - Document divided into 9 chunks
# 2025-12-25 21:08:51,309 - INFO - Step 3: Generating embeddings
# 2025-12-25 21:08:51,309 - INFO - Generating embeddings for 9 chunks
# 2025-12-25 21:08:51,582 - INFO - Embeddings generation completed
# 2025-12-25 21:08:51,583 - INFO - Step 4: Running inference phase (ETI)
# 2025-12-25 21:08:51,614 - INFO - Inferred 23 facts from chunk 110225.md_256069b4-ae98-4878-9cf1-4e640a964315
# 2025-12-25 21:08:51,644 - INFO - Inferred 26 facts from chunk 110225.md_387f7b05-f9f1-41ce-b2db-a6a1aed8f24b
# 2025-12-25 21:08:51,670 - INFO - Inferred 25 facts from chunk 110225.md_1cca5947-3a97-4299-a0b7-f404603cc46e
# 2025-12-25 21:08:51,697 - INFO - Inferred 18 facts from chunk 110225.md_ca2e3477-ed5a-4d38-a6c6-47d8a3a74a35
# 2025-12-25 21:08:51,724 - INFO - Inferred 17 facts from chunk 110225.md_7c5b12c8-9fea-4ee1-8558-61ea9b1f09fc
# 2025-12-25 21:08:51,747 - INFO - Inferred 24 facts from chunk 110225.md_c9fc28d3-50a6-4732-8279-0c01d6c76db8
# 2025-12-25 21:08:51,771 - INFO - Inferred 22 facts from chunk 110225.md_91843849-da9e-493f-b936-f66f56c2a414
# 2025-12-25 21:08:51,795 - INFO - Inferred 20 facts from chunk 110225.md_b85954fa-b1f7-424a-9aba-7e6f2c2a424a
# 2025-12-25 21:08:51,802 - INFO - Inferred 6 facts from chunk 110225.md_70d2ba25-a78f-4f6d-91f6-79357c747088
# 2025-12-25 21:08:51,803 - INFO - Inference phase completed. Generated 181 facts
# 2025-12-25 21:08:51,804 - INFO - Step 5: Setting up indexes
# 2025-12-25 21:08:51,805 - INFO - Setting up all indexes
# 2025-12-25 21:08:51,805 - INFO - Connecting to Neo4j at bolt://localhost:7687 with user neo4j
# 2025-12-25 21:08:53,893 - INFO - Successfully connected to Neo4j
# 2025-12-25 21:08:53,912 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Schema.IndexOrConstraintAlreadyExists} {category: SCHEMA} {title: `CREATE RANGE INDEX chunk_consecutive_idx IF NOT EXISTS FOR (e:Chunk) ON (e.chunk_id_consecutive)` has no effect.} {description: `RANGE INDEX chunk_consecutive_idx FOR (e:Chunk) ON (e.chunk_id_consecutive)` already exists.} {position: None} for query: '\n        CREATE INDEX chunk_consecutive_idx IF NOT EXISTS\n        FOR (c:Chunk)\n        ON (c.chunk_id_consecutive)\n        '
# 2025-12-25 21:08:53,916 - INFO - Regular index 'chunk_consecutive_idx' created successfully
# 2025-12-25 21:08:54,001 - INFO - Vector index 'chunk_embeddings' already exists
# 2025-12-25 21:08:54,012 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Schema.IndexOrConstraintAlreadyExists} {category: SCHEMA} {title: `CREATE FULLTEXT INDEX chunk_content IF NOT EXISTS FOR (e:Chunk) ON EACH [e.page_content] OPTIONS {indexConfig: {`fulltext.analyzer`: "spanish", `fulltext.eventually_consistent`: false}}` has no effect.} {description: `FULLTEXT INDEX chunk_content FOR (e:Chunk) ON EACH [e.page_content]` already exists.} {position: None} for query: "\n        CREATE FULLTEXT INDEX chunk_content IF NOT EXISTS\n        FOR (c:Chunk)\n        ON EACH [c.page_content]\n        OPTIONS {\n            indexConfig: {\n                `fulltext.analyzer`: 'spanish',\n                `fulltext.eventually_consistent`: false\n            }\n        }\n        "
# 2025-12-25 21:08:54,013 - INFO - Full-text index 'chunk_content' created successfully
# 2025-12-25 21:08:54,014 - INFO - All indexes setup completed
# 2025-12-25 21:08:54,015 - INFO - Step 6: Persisting chunks with pattern FILE_PAGE_CHUNK
# 2025-12-25 21:08:54,021 - INFO - Using existing save_batch() for FILE_PAGE_CHUNK pattern
# 2025-12-25 21:08:54,022 - INFO - Connecting to Neo4j at bolt://localhost:7687 with user neo4j
# 2025-12-25 21:08:56,079 - INFO - Successfully connected to Neo4j
# 2025-12-25 21:09:00,201 - INFO - Step 7: Persisting 181 facts
# 2025-12-25 21:09:01,318 - INFO - Successfully saved 181 facts to Neo4j
# 2025-12-25 21:09:01,319 - INFO - Successfully persisted 181 facts
# 2025-12-25 21:09:01,320 - INFO - Step 8: Creating chunk relationships
# 2025-12-25 21:09:01,484 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (c2))} {position: line: 2, column: 5, offset: 5} for query: '\n    MATCH (c1:Chunk),(c2:Chunk)\n    WHERE c1.chunk_id_consecutive + 1 = c2.chunk_id_consecutive\n    MERGE (c1)-[:NEXT_CHUNK]->(c2)\n    '
# 2025-12-25 21:09:01,492 - INFO - Chunk relationships created successfully
# 2025-12-25 21:09:01,492 - INFO - Document ingestion completed. Created 9 chunks and 181 facts
# ✅ Documento ingerido exitosamente!
#    Total de chunks: 9
#    Chunks con embeddings: 9
#
# 📄 Primeros 2 chunks:
#
#    Chunk 1:
#    - ID: 110225.md_256069b4-ae98-4878-9cf1-4e640a964315...
#    - Contenido: Incluso es lo primero que se abrio, quiza lo que me falta en este momento es la palabra, y necesite ...
#    - Consecutivo: 1
#    - Embeddings: 384 dimensiones
#
#    Chunk 2:
#    - ID: 110225.md_387f7b05-f9f1-41ce-b2db-a6a1aed8f24b...
#    - Contenido: quiero narrar como estoy desarrollando la vision de mi mismo, la que quiero para mi, el humano que q...
#    - Consecutivo: 2
#    - Embeddings: 384 dimensiones

# %% [markdown]
# ### 3.2 Ingerir Texto Plano (.txt)
#
# Los archivos de texto tienen detección automática de encoding (UTF-8, Windows-1252, Latin-1, etc.).

# %%
# Ingerir archivo de texto
txt_file = data_path / "AnnyLetter.txt"

if txt_file.exists():
    print(f"📥 Ingiriendo: {txt_file.name}")
    chunks_txt = ungraph.ingest_document(
        txt_file,
        chunk_size=500,
        chunk_overlap=100,
        clean_text=True
    )
    print(f"✅ Documento ingerido exitosamente!")
    print(f"   Total de chunks: {len(chunks_txt)}")
else:
    print(f"⚠️  Archivo no encontrado: {txt_file}")
# Out:
# 2025-12-25 21:09:01,503 - INFO - CUDA no disponible, usando CPU para embeddings.
# 2025-12-25 21:09:01,507 - INFO - Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# 📥 Ingiriendo: AnnyLetter.txt
# 2025-12-25 21:09:03,849 - INFO - Embedding service initialized with model: sentence-transformers/all-MiniLM-L6-v2
# 2025-12-25 21:09:03,850 - INFO - Loading spaCy model: en_core_web_sm
# 2025-12-25 21:09:04,233 - INFO - spaCy model loaded successfully
# 2025-12-25 21:09:04,234 - INFO - Starting document ingestion: D:\projects\Ungraph\src\data\AnnyLetter.txt
# 2025-12-25 21:09:04,234 - INFO - Using pattern: FILE_PAGE_CHUNK
# 2025-12-25 21:09:04,235 - INFO - Step 1: Loading document
# 2025-12-25 21:09:04,236 - INFO - Cargando archivo de texto: D:\projects\Ungraph\src\data\AnnyLetter.txt
# 2025-12-25 21:09:04,278 - INFO - Codificación detectada por chardet: iso-8859-1 (confianza: 73.00%)
# 2025-12-25 21:09:04,279 - INFO - Codificación detectada: iso-8859-1
# 2025-12-25 21:09:04,280 - INFO - Archivo cargado exitosamente con codificación: iso-8859-1
# 2025-12-25 21:09:06,023 - INFO - Inferred 13 facts from chunk AnnyLetter.txt_d19a384f-a734-42f5-9ac4-5a2a132f4170
# 2025-12-25 21:09:06,043 - INFO - Inferred 4 facts from chunk AnnyLetter.txt_87f45c1e-5864-4de3-9515-8525f8c9920e
# 2025-12-25 21:09:06,063 - INFO - Inferred 6 facts from chunk AnnyLetter.txt_b1528580-9eb6-4735-8d8d-0799f325dbdf
# 2025-12-25 21:09:06,077 - INFO - Inferred 6 facts from chunk AnnyLetter.txt_18fc264e-54ba-4613-9d99-fc8307a59faf
# 2025-12-25 21:09:06,106 - INFO - Inferred 11 facts from chunk AnnyLetter.txt_b30f5bda-b37d-4eb4-b10f-0979ae553cf4
# 2025-12-25 21:09:06,143 - INFO - Inferred 12 facts from chunk AnnyLetter.txt_e11ca841-7a43-4ea8-9335-f33727c088bc
# 2025-12-25 21:09:06,166 - INFO - Inferred 8 facts from chunk AnnyLetter.txt_64fb56dc-2a13-44a3-8434-a4b79b859c56
# 2025-12-25 21:09:06,185 - INFO - Inferred 5 facts from chunk AnnyLetter.txt_4137accb-35d2-483d-9892-827ecbda6516
# 2025-12-25 21:09:06,199 - INFO - Inferred 5 facts from chunk AnnyLetter.txt_61a652b7-8240-4473-be99-0b39a4627288
# 2025-12-25 21:09:06,199 - INFO - Inference phase completed. Generated 436 facts
# 2025-12-25 21:09:06,200 - INFO - Step 5: Setting up indexes
# 2025-12-25 21:09:06,202 - INFO - Setting up all indexes
# 2025-12-25 21:09:06,203 - INFO - Connecting to Neo4j at bolt://localhost:7687 with user neo4j
# 2025-12-25 21:09:08,269 - INFO - Successfully connected to Neo4j
# 2025-12-25 21:09:08,272 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Schema.IndexOrConstraintAlreadyExists} {category: SCHEMA} {title: `CREATE RANGE INDEX chunk_consecutive_idx IF NOT EXISTS FOR (e:Chunk) ON (e.chunk_id_consecutive)` has no effect.} {description: `RANGE INDEX chunk_consecutive_idx FOR (e:Chunk) ON (e.chunk_id_consecutive)` already exists.} {position: None} for query: '\n        CREATE INDEX chunk_consecutive_idx IF NOT EXISTS\n        FOR (c:Chunk)\n        ON (c.chunk_id_consecutive)\n        '
# 2025-12-25 21:09:08,273 - INFO - Regular index 'chunk_consecutive_idx' created successfully
# 2025-12-25 21:09:08,284 - INFO - Vector index 'chunk_embeddings' already exists
# 2025-12-25 21:09:08,291 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Schema.IndexOrConstraintAlreadyExists} {category: SCHEMA} {title: `CREATE FULLTEXT INDEX chunk_content IF NOT EXISTS FOR (e:Chunk) ON EACH [e.page_content] OPTIONS {indexConfig: {`fulltext.analyzer`: "spanish", `fulltext.eventually_consistent`: false}}` has no effect.} {description: `FULLTEXT INDEX chunk_content FOR (e:Chunk) ON EACH [e.page_content]` already exists.} {position: None} for query: "\n        CREATE FULLTEXT INDEX chunk_content IF NOT EXISTS\n        FOR (c:Chunk)\n        ON EACH [c.page_content]\n        OPTIONS {\n            indexConfig: {\n                `fulltext.analyzer`: 'spanish',\n                `fulltext.eventually_consistent`: false\n            }\n        }\n        "
# 2025-12-25 21:09:08,294 - INFO - Full-text index 'chunk_content' created successfully
# 2025-12-25 21:09:08,296 - INFO - All indexes setup completed
# 2025-12-25 21:09:08,299 - INFO - Step 6: Persisting chunks with pattern FILE_PAGE_CHUNK
# 2025-12-25 21:09:08,300 - INFO - Using existing save_batch() for FILE_PAGE_CHUNK pattern
# 2025-12-25 21:09:08,303 - INFO - Connecting to Neo4j at bolt://localhost:7687 with user neo4j
# 2025-12-25 21:09:10,370 - INFO - Successfully connected to Neo4j
# 2025-12-25 21:09:27,436 - INFO - Step 7: Persisting 436 facts
# 2025-12-25 21:09:28,767 - INFO - Successfully saved 436 facts to Neo4j
# 2025-12-25 21:09:28,768 - INFO - Successfully persisted 436 facts
# 2025-12-25 21:09:28,770 - INFO - Step 8: Creating chunk relationships
# 2025-12-25 21:09:28,828 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (c2))} {position: line: 2, column: 5, offset: 5} for query: '\n    MATCH (c1:Chunk),(c2:Chunk)\n    WHERE c1.chunk_id_consecutive + 1 = c2.chunk_id_consecutive\n    MERGE (c1)-[:NEXT_CHUNK]->(c2)\n    '
# 2025-12-25 21:09:28,837 - INFO - Chunk relationships created successfully
# 2025-12-25 21:09:28,839 - INFO - Document ingestion completed. Created 45 chunks and 436 facts
# ✅ Documento ingerido exitosamente!
#    Total de chunks: 45

# %% [markdown]
# ### 3.3 Ingerir Word (.docx)
#
# Los documentos Word se procesan manteniendo la estructura y formato.

# %%
# Ingerir archivo Word
docx_file = data_path / "Usar símboles de silencio de corchea.docx"

if docx_file.exists():
    print(f"📥 Ingiriendo: {docx_file.name}")
    chunks_docx = ungraph.ingest_document(
        docx_file,
        chunk_size=1000,
        chunk_overlap=200,
        clean_text=True
    )
    print(f"✅ Documento ingerido exitosamente!")
    print(f"   Total de chunks: {len(chunks_docx)}")
    
    # Mostrar metadatos específicos de Word
    if chunks_docx:
        print(f"\n📋 Metadatos del primer chunk:")
        for key, value in list(chunks_docx[0].metadata.items())[:5]:
            print(f"   - {key}: {value}")
else:
    print(f"⚠️  Archivo no encontrado: {docx_file}")
# Out:
# 2025-12-25 21:09:28,851 - INFO - CUDA no disponible, usando CPU para embeddings.
# 2025-12-25 21:09:28,854 - INFO - Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# 📥 Ingiriendo: Usar símboles de silencio de corchea.docx
# 2025-12-25 21:09:31,190 - INFO - Embedding service initialized with model: sentence-transformers/all-MiniLM-L6-v2
# 2025-12-25 21:09:31,191 - INFO - Loading spaCy model: en_core_web_sm
# 2025-12-25 21:09:31,568 - INFO - spaCy model loaded successfully
# 2025-12-25 21:09:31,569 - INFO - Starting document ingestion: D:\projects\Ungraph\src\data\Usar símboles de silencio de corchea.docx
# 2025-12-25 21:09:31,570 - INFO - Using pattern: FILE_PAGE_CHUNK
# 2025-12-25 21:09:31,571 - INFO - Step 1: Loading document
# 2025-12-25 21:09:31,571 - INFO - Cargando archivo Word: D:\projects\Ungraph\src\data\Usar símboles de silencio de corchea.docx
# 2025-12-25 21:09:31,969 - INFO - Starting text cleaning.
# 2025-12-25 21:09:31,970 - INFO - Text cleaning completed.
# 2025-12-25 21:09:31,971 - INFO - Archivo cargado exitosamente. Documentos generados: 1
# 2025-12-25 21:09:31,971 - INFO - Step 2: Chunking document
# 2025-12-25 21:09:31,972 - INFO - Chunking document: Usar símboles de silencio de corchea.docx
# 2025-12-25 21:09:31,977 - INFO - Document divided into 27 chunks
# 2025-12-25 21:09:31,977 - INFO - Step 3: Generating embeddings
# 2025-12-25 21:09:31,978 - INFO - Generating embeddings for 27 chunks
# 2025-12-25 21:09:32,788 - INFO - Embeddings generation completed
# 2025-12-25 21:09:32,789 - INFO - Step 4: Running inference phase (ETI)
# 2025-12-25 21:09:33,349 - INFO - Inferred 25 facts from chunk Usar símboles de silencio de corchea.docx_e5c1e0cd-c2cf-4e0c-b587-7ac416980729
# 2025-12-25 21:09:33,381 - INFO - Inferred 17 facts from chunk Usar símboles de silencio de corchea.docx_b22910ad-eef8-490c-80f7-d7d47514bd1c
# 2025-12-25 21:09:33,423 - INFO - Inferred 17 facts from chunk Usar símboles de silencio de corchea.docx_5004b0b5-62cb-4d27-87fb-d2395ad47e96
# 2025-12-25 21:09:33,460 - INFO - Inferred 20 facts from chunk Usar símboles de silencio de corchea.docx_0f73f2b6-4fd4-4523-8120-9a6648a583e4
# 2025-12-25 21:09:33,490 - INFO - Inferred 19 facts from chunk Usar símboles de silencio de corchea.docx_928a4265-38cc-4f3c-8805-6679e7b16979
# 2025-12-25 21:09:33,511 - INFO - Inferred 23 facts from chunk Usar símboles de silencio de corchea.docx_467d6efe-c4bf-4dac-aa92-22f10a3f6107
# 2025-12-25 21:09:33,540 - INFO - Inferred 21 facts from chunk Usar símboles de silencio de corchea.docx_da532316-9a5c-4782-8671-589833602089
# 2025-12-25 21:09:33,562 - INFO - Inferred 9 facts from chunk Usar símboles de silencio de corchea.docx_54bae458-e2c0-49ef-adda-11bf8c2f81b1
# 2025-12-25 21:09:33,563 - INFO - Inference phase completed. Generated 515 facts
# 2025-12-25 21:09:33,564 - INFO - Step 5: Setting up indexes
# 2025-12-25 21:09:33,564 - INFO - Setting up all indexes
# 2025-12-25 21:09:33,565 - INFO - Connecting to Neo4j at bolt://localhost:7687 with user neo4j
# 2025-12-25 21:09:35,649 - INFO - Successfully connected to Neo4j
# 2025-12-25 21:09:35,653 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Schema.IndexOrConstraintAlreadyExists} {category: SCHEMA} {title: `CREATE RANGE INDEX chunk_consecutive_idx IF NOT EXISTS FOR (e:Chunk) ON (e.chunk_id_consecutive)` has no effect.} {description: `RANGE INDEX chunk_consecutive_idx FOR (e:Chunk) ON (e.chunk_id_consecutive)` already exists.} {position: None} for query: '\n        CREATE INDEX chunk_consecutive_idx IF NOT EXISTS\n        FOR (c:Chunk)\n        ON (c.chunk_id_consecutive)\n        '
# 2025-12-25 21:09:35,655 - INFO - Regular index 'chunk_consecutive_idx' created successfully
# 2025-12-25 21:09:35,660 - INFO - Vector index 'chunk_embeddings' already exists
# 2025-12-25 21:09:35,664 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Schema.IndexOrConstraintAlreadyExists} {category: SCHEMA} {title: `CREATE FULLTEXT INDEX chunk_content IF NOT EXISTS FOR (e:Chunk) ON EACH [e.page_content] OPTIONS {indexConfig: {`fulltext.analyzer`: "spanish", `fulltext.eventually_consistent`: false}}` has no effect.} {description: `FULLTEXT INDEX chunk_content FOR (e:Chunk) ON EACH [e.page_content]` already exists.} {position: None} for query: "\n        CREATE FULLTEXT INDEX chunk_content IF NOT EXISTS\n        FOR (c:Chunk)\n        ON EACH [c.page_content]\n        OPTIONS {\n            indexConfig: {\n                `fulltext.analyzer`: 'spanish',\n                `fulltext.eventually_consistent`: false\n            }\n        }\n        "
# 2025-12-25 21:09:35,666 - INFO - Full-text index 'chunk_content' created successfully
# 2025-12-25 21:09:35,666 - INFO - All indexes setup completed
# 2025-12-25 21:09:35,667 - INFO - Step 6: Persisting chunks with pattern FILE_PAGE_CHUNK
# 2025-12-25 21:09:35,667 - INFO - Using existing save_batch() for FILE_PAGE_CHUNK pattern
# 2025-12-25 21:09:35,668 - INFO - Connecting to Neo4j at bolt://localhost:7687 with user neo4j
# 2025-12-25 21:09:37,733 - INFO - Successfully connected to Neo4j
# 2025-12-25 21:09:48,047 - INFO - Step 7: Persisting 515 facts
# 2025-12-25 21:09:49,428 - INFO - Successfully saved 515 facts to Neo4j
# 2025-12-25 21:09:49,429 - INFO - Successfully persisted 515 facts
# 2025-12-25 21:09:49,429 - INFO - Step 8: Creating chunk relationships
# 2025-12-25 21:09:49,648 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (c2))} {position: line: 2, column: 5, offset: 5} for query: '\n    MATCH (c1:Chunk),(c2:Chunk)\n    WHERE c1.chunk_id_consecutive + 1 = c2.chunk_id_consecutive\n    MERGE (c1)-[:NEXT_CHUNK]->(c2)\n    '
# 2025-12-25 21:09:49,679 - INFO - Chunk relationships created successfully
# 2025-12-25 21:09:49,680 - INFO - Document ingestion completed. Created 27 chunks and 515 facts
# ✅ Documento ingerido exitosamente!
#    Total de chunks: 27
#
# 📋 Metadatos del primer chunk:
#    - filename: Usar símboles de silencio de corchea.docx
#    - file_type: docx
#    - file_path: D:\projects\Ungraph\src\data\Usar símboles de silencio de corchea.docx
#    - source: D:\projects\Ungraph\src\data\Usar símboles de silencio de corchea.docx

# %% [markdown]
# ### 3.4 Ingerir PDF (.pdf)
#
# Los PDFs se procesan usando IBM Docling, que proporciona mejor extracción de texto, estructura, tablas e imágenes.

# %%
# Buscar archivo PDF en la carpeta data
pdf_files = list(data_path.glob("*.pdf"))

if pdf_files:
    pdf_file = pdf_files[0]
    print(f"📥 Ingiriendo PDF: {pdf_file.name}")
    print(f"   Tamaño: {pdf_file.stat().st_size / 1024:.1f} KB")
    
    try:
        chunks_pdf = ungraph.ingest_document(
            pdf_file,
            chunk_size=1000,
            chunk_overlap=200,
            clean_text=True
        )
        print(f"✅ PDF ingerido exitosamente!")
        print(f"   Total de chunks: {len(chunks_pdf)}")
        
        # Mostrar metadatos específicos de PDF (pueden incluir page_number, document_structure, etc.)
        if chunks_pdf:
            print(f"\n📋 Metadatos del primer chunk:")
            for key, value in list(chunks_pdf[0].metadata.items())[:5]:
                print(f"   - {key}: {value}")
    except ImportError as e:
        print(f"❌ Error: {e}")
        print("   Instala langchain-docling con: pip install langchain-docling")
    except Exception as e:
        print(f"❌ Error procesando PDF: {e}")
else:
    print("⚠️  No se encontraron archivos PDF en la carpeta data")
    print("   Puedes añadir un PDF para probar esta funcionalidad")
# Out:
# 2025-12-25 21:09:49,694 - INFO - CUDA no disponible, usando CPU para embeddings.
# 2025-12-25 21:09:49,698 - INFO - Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# 📥 Ingiriendo PDF: peach-et-al-2014-qsar-modeling-of-imbalanced-high-throughput-screening-data-in-pubchem.pdf
#    Tamaño: 447.4 KB
# 2025-12-25 21:09:52,015 - INFO - Embedding service initialized with model: sentence-transformers/all-MiniLM-L6-v2
# 2025-12-25 21:09:52,016 - INFO - Loading spaCy model: en_core_web_sm
# 2025-12-25 21:09:52,453 - INFO - spaCy model loaded successfully
# 2025-12-25 21:09:52,454 - INFO - Starting document ingestion: D:\projects\Ungraph\src\data\peach-et-al-2014-qsar-modeling-of-imbalanced-high-throughput-screening-data-in-pubchem.pdf
# 2025-12-25 21:09:52,456 - INFO - Using pattern: FILE_PAGE_CHUNK
# 2025-12-25 21:09:52,458 - INFO - Step 1: Loading document
# 2025-12-25 21:09:52,459 - INFO - Cargando archivo PDF con Docling: D:\projects\Ungraph\src\data\peach-et-al-2014-qsar-modeling-of-imbalanced-high-throughput-screening-data-in-pubchem.pdf
- INFO - Text cleaning completed.
# 2025-12-25 21:10:20,959 - INFO - Starting text cleaning.
# 2025-12-25 21:10:20,960 - INFO - Text cleaning completed.
# 2025-12-25 21:10:20,962 - INFO - PDF cargado exitosamente con Docling. Documentos generados: 80
# 2025-12-25 21:10:20,967 - INFO - Step 2: Chunking document
# 2025-12-25 21:10:20,972 - INFO - Chunking document: peach-et-al-2014-qsar-modeling-of-imbalanced-high-throughput-screening-data-in-pubchem.pdf
# 2025-12-25 21:10:20,973 - INFO - Document divided into 1 chunks
# 2025-12-25 21:10:20,974 - INFO - Step 3: Generating embeddings
# 2025-12-25 21:10:20,975 - INFO - Generating embeddings for 1 chunks
# 2025-12-25 21:10:21,006 - INFO - Embeddings generation completed
# 2025-12-25 21:10:21,007 - INFO - Step 4: Running inference phase (ETI)
# 2025-12-25 21:10:21,013 - INFO - Inferred 1 facts from chunk peach-et-al-2014-qsar-modeling-of-imbalanced-high-throughput-screening-data-in-pubchem.pdf_268dc13e-4190-4f38-b6bf-6c48decd4158
# 2025-12-25 21:10:21,013 - INFO - Inference phase completed. Generated 1 facts
# 2025-12-25 21:10:21,014 - INFO - Step 5: Setting up indexes
# 2025-12-25 21:10:21,014 - INFO - Setting up all indexes
# 2025-12-25 21:10:21,015 - INFO - Connecting to Neo4j at bolt://localhost:7687 with user neo4j
# 2025-12-25 21:10:23,058 - INFO - Successfully connected to Neo4j
# 2025-12-25 21:10:23,067 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Schema.IndexOrConstraintAlreadyExists} {category: SCHEMA} {title: `CREATE RANGE INDEX chunk_consecutive_idx IF NOT EXISTS FOR (e:Chunk) ON (e.chunk_id_consecutive)` has no effect.} {description: `RANGE INDEX chunk_consecutive_idx FOR (e:Chunk) ON (e.chunk_id_consecutive)` already exists.} {position: None} for query: '\n        CREATE INDEX chunk_consecutive_idx IF NOT EXISTS\n        FOR (c:Chunk)\n        ON (c.chunk_id_consecutive)\n        '
# 2025-12-25 21:10:23,070 - INFO - Regular index 'chunk_consecutive_idx' created successfully
# 2025-12-25 21:10:23,075 - INFO - Vector index 'chunk_embeddings' already exists
# 2025-12-25 21:10:23,085 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Schema.IndexOrConstraintAlreadyExists} {category: SCHEMA} {title: `CREATE FULLTEXT INDEX chunk_content IF NOT EXISTS FOR (e:Chunk) ON EACH [e.page_content] OPTIONS {indexConfig: {`fulltext.analyzer`: "spanish", `fulltext.eventually_consistent`: false}}` has no effect.} {description: `FULLTEXT INDEX chunk_content FOR (e:Chunk) ON EACH [e.page_content]` already exists.} {position: None} for query: "\n        CREATE FULLTEXT INDEX chunk_content IF NOT EXISTS\n        FOR (c:Chunk)\n        ON EACH [c.page_content]\n        OPTIONS {\n            indexConfig: {\n                `fulltext.analyzer`: 'spanish',\n                `fulltext.eventually_consistent`: false\n            }\n        }\n        "
# 2025-12-25 21:10:23,087 - INFO - Full-text index 'chunk_content' created successfully
# 2025-12-25 21:10:23,088 - INFO - All indexes setup completed
# 2025-12-25 21:10:23,088 - INFO - Step 6: Persisting chunks with pattern FILE_PAGE_CHUNK
# 2025-12-25 21:10:23,089 - INFO - Using existing save_batch() for FILE_PAGE_CHUNK pattern
# 2025-12-25 21:10:23,089 - INFO - Connecting to Neo4j at bolt://localhost:7687 with user neo4j
# 2025-12-25 21:10:25,159 - INFO - Successfully connected to Neo4j
# 2025-12-25 21:10:25,822 - INFO - Step 7: Persisting 1 facts
# 2025-12-25 21:10:26,912 - INFO - Successfully saved 1 facts to Neo4j
# 2025-12-25 21:10:26,914 - INFO - Successfully persisted 1 facts
# 2025-12-25 21:10:26,916 - INFO - Step 8: Creating chunk relationships
# 2025-12-25 21:10:26,937 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Statement.CartesianProduct} {category: PERFORMANCE} {title: This query builds a cartesian product between disconnected patterns.} {description: If a part of a query contains multiple disconnected patterns, this will build a cartesian product between all those parts. This may produce a large amount of data and slow down query processing. While occasionally intended, it may often be possible to reformulate the query that avoids the use of this cross product, perhaps by adding a relationship between the different parts or by using OPTIONAL MATCH (identifier is: (c2))} {position: line: 2, column: 5, offset: 5} for query: '\n    MATCH (c1:Chunk),(c2:Chunk)\n    WHERE c1.chunk_id_consecutive + 1 = c2.chunk_id_consecutive\n    MERGE (c1)-[:NEXT_CHUNK]->(c2)\n    '
# 2025-12-25 21:10:26,939 - INFO - Chunk relationships created successfully
# 2025-12-25 21:10:26,940 - INFO - Document ingestion completed. Created 1 chunks and 1 facts
# ✅ PDF ingerido exitosamente!
#    Total de chunks: 1
#
# 📋 Metadatos del primer chunk:
#    - filename: peach-et-al-2014-qsar-modeling-of-imbalanced-high-throughput-screening-data-in-pubchem.pdf
#    - file_type: pdf
#    - file_path: D:\projects\Ungraph\src\data\peach-et-al-2014-qsar-modeling-of-imbalanced-high-throughput-screening-data-in-pubchem.pdf
#    - source: D:\projects\Ungraph\src\data\peach-et-al-2014-qsar-modeling-of-imbalanced-high-throughput-screening-data-in-pubchem.pdf
#    - dl_meta: {'schema_name': 'docling_core.transforms.chunker.DocMeta', 'version': '1.0.0', 'doc_items': [{'self_ref': '#/texts/3', 'parent': {'$ref': '#/body'}, 'children': [], 'content_layer': 'body', 'label': 'text', 'prov': [{'page_no': 1, 'bbox': {'l': 536.201, 't': 757.8809995117188, 'r': 557.425, 'b': 750.5289995117188, 'coord_origin': 'BOTTOMLEFT'}, 'charspan': [0, 7]}, {'page_no': 1, 'bbox': {'l': 506.211, 't': 741.6099995117188, 'r': 564.379, 'b': 734.2579995117188, 'coord_origin': 'BOTTOMLEFT'}, 'charspan': [8, 25]}]}], 'origin': {'mimetype': 'application/pdf', 'binary_hash': 822283243243562234, 'filename': 'peach-et-al-2014-qsar-modeling-of-imbalanced-high-throughput-screening-data-in-pubchem.pdf'}}

# %% [markdown]
# ## Parte 4: Obtener Recomendaciones de Chunking
#
# Antes de ingerir, podemos obtener recomendaciones sobre la mejor estrategia de chunking para cada documento.

# %%
# Obtener recomendación para un archivo
markdown_file = data_path / "110225.md"

if markdown_file.exists():
    print(f"📊 Analizando: {markdown_file.name}")
    recommendation = ungraph.suggest_chunking_strategy(markdown_file)
    
    print(f"\n✅ Recomendación obtenida:")
    print(f"   Estrategia: {recommendation.strategy}")
    print(f"   Chunk size: {recommendation.chunk_size}")
    print(f"   Chunk overlap: {recommendation.chunk_overlap}")
    print(f"   Quality score: {recommendation.quality_score:.2f}")
    print(f"\n📝 Explicación:")
    print(recommendation.explanation)
    
    # Usar la recomendación para ingerir
    print(f"\n💡 Puedes usar esta recomendación al ingerir:")
    print(f"   chunks = ungraph.ingest_document(")
    print(f"       '{markdown_file.name}',")
    print(f"       chunk_size={recommendation.chunk_size},")
    print(f"       chunk_overlap={recommendation.chunk_overlap}")
    print(f"   )")
else:
    print(f"⚠️  Archivo no encontrado: {markdown_file}")
# Out:
# 2025-12-25 21:10:26,955 - INFO - Cargando archivo Markdown: D:\projects\Ungraph\src\data\110225.md
# 2025-12-25 21:10:26,973 - INFO - Archivo cargado exitosamente. Documentos generados: 1
# 2025-12-25 21:10:26,975 - INFO - Tipo de documento detectado: markdown
# 2025-12-25 21:10:26,976 - INFO - Estructura: 0 headers, 29 párrafos, 1132 palabras
# 2025-12-25 21:10:26,976 - INFO - Parámetros calculados: chunk_size=2000, chunk_overlap=300
# 2025-12-25 21:10:26,977 - INFO - Estrategias candidatas: ['recursive', 'character']
# 2025-12-25 21:10:26,980 - INFO - Estrategia recursive: 4 chunks, score=70.80
# 2025-12-25 21:10:26,982 - INFO - Estrategia character: 4 chunks, score=70.80
# 2025-12-25 21:10:26,983 - INFO - Mejor estrategia seleccionada: recursive (score: 70.80)
# 📊 Analizando: 110225.md
#
# ✅ Recomendación obtenida:
#    Estrategia: recursive
#    Chunk size: 2000
#    Chunk overlap: 300
#    Quality score: 70.80
#
# 📝 Explicación:
# The strategy 'recursive' is recommended because:
# - The document is Markdown with header structure
# - The document has 29 paragraphs
# - Will generate approximately 4 chunks
# - Average chunk size: 1792 characters
# - Quality score: 70.80/1.0
#
# 💡 Puedes usar esta recomendación al ingerir:
#    chunks = ungraph.ingest_document(
#        '110225.md',
#        chunk_size=2000,
#        chunk_overlap=300
#    )

# %% [markdown]
# ## Parte 5: Verificar Datos en el Grafo
#
# Verifiquemos que los documentos se guardaron correctamente en Neo4j.

# %%
# Verificar datos en el grafo
from src.utils.graph_operations import graph_session

driver = graph_session()
try:
    with driver.session() as session:
        # Contar nodos por tipo
        result = session.run("MATCH (f:File) RETURN count(f) as count")
        file_count = result.single()["count"]
        
        result = session.run("MATCH (p:Page) RETURN count(p) as count")
        page_count = result.single()["count"]
        
        result = session.run("MATCH (c:Chunk) RETURN count(c) as count")
        chunk_count = result.single()["count"]
        
        print("📊 Datos en el grafo:")
        print(f"   Files: {file_count}")
        print(f"   Pages: {page_count}")
        print(f"   Chunks: {chunk_count}")
        
        # Listar archivos ingeridos
        if file_count > 0:
            result = session.run("MATCH (f:File) RETURN f.filename as filename ORDER BY f.filename")
            print(f"\n📄 Archivos ingeridos:")
            for record in result:
                print(f"   - {record['filename']}")
finally:
    driver.close()
# Out:
# 2025-12-25 21:10:27,000 - INFO - Connecting to Neo4j at bolt://localhost:7687 with user neo4j
# 2025-12-25 21:10:29,052 - INFO - Successfully connected to Neo4j
# 📊 Datos en el grafo:
#    Files: 5
#    Pages: 6
#    Chunks: 253
#
# 📄 Archivos ingeridos:
#    - 110225.md
#    - AnnyLetter.txt
#    - Usar símboles de silencio de corchea.docx
#    - peach-et-al-2014-qsar-modeling-of-imbalanced-high-throughput-screening-data-in-pubchem.pdf
#    - test_document.md

# %% [markdown]
# ## Resumen y Mejores Prácticas
#
# ### Formatos Soportados
#
# | Formato | Extensión | Características |
# |---------|-----------|----------------|
# | Markdown | .md | Estructura preservada, headers detectados |
# | Texto | .txt | Detección automática de encoding |
# | Word | .docx | Estructura y formato preservados |
# | PDF | .pdf | Extracción avanzada con Docling (tablas, imágenes, estructura) |
#
# ### Mejores Prácticas
#
# 1. **Usar recomendaciones**: `suggest_chunking_strategy()` ayuda a elegir parámetros óptimos
# 2. **Ajustar chunk_size**:
#    - Textos largos: 1000-2000 caracteres
#    - Textos cortos: 500-1000 caracteres
# 3. **Overlap razonable**: 10-20% del chunk_size (ej: 200 para chunk_size=1000)
# 4. **Limpiar texto**: `clean_text=True` mejora la calidad de embeddings
# 5. **Verificar carga**: Siempre verifica que los documentos se cargaron correctamente
#
# ### Siguiente Paso
#
# Una vez que has ingerido documentos, continúa con:
# - **2.1 Graph Pattern Construction** - Construir estructuras de grafo personalizadas
# - **2.2 Smart Chunking Strategies** - Optimizar estrategias de chunking
# - **3.1 Entity Extraction & Facts** - Extraer entidades y facts (fase Inference)
#
# ## Referencias
#
# - [Guía de Ingesta](../../docs/guides/ingestion.md)
# - [API Pública](../../docs/api/public-api.md)
# - [Document Loader Service](../../src/infrastructure/services/langchain_document_loader_service.py)
