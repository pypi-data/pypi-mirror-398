# %% [markdown]
# ## Hyperparameter-Tuning each Classifier at every Prediction
#
# Just like in [classification.ipynb](./classification.ipynb), we will use the UCI ML Breast Cancer Wisconsin dataset again.
#
# As seen in the previous example, ``LTFMSelector`` can use any predicton model as long as it comes with ``fit`` and ``predict`` call functions. This allows one to also use tools like scikit-learn's ``GridSearchCV`` to carry out hyperparameter tuning by grid-searching a user-defined range of hyperparameters per prediction model.

# %%
from ltfmselector import LTFMSelector

import numpy as np
import pandas as pd
from sklearn.datasets import load_breast_cancer

# %% [markdown]
# Pre-processing the datasets

# %%
# Load breast cancer dataset
cancer_dataset = load_breast_cancer()

# Get data
X = cancer_dataset['data']

# Get target
y = cancer_dataset['target']
# - 0: malignant tumor
# - 1: benign tumor

# Get feature names
feature_names = cancer_dataset['feature_names']

# Get description
dataset_description = cancer_dataset['DESCR']

# Convert data into pandas DataFrame
cancer_df = pd.DataFrame(
    np.c_[X, y], columns = np.append(feature_names, ['target'])
)

# Split the dataset for training and test
X_df = cancer_df.drop(['target'], axis=1)
y_df = cancer_df['target']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_df, y_df, test_size=0.2, random_state=5)

y_train = y_train.reset_index(drop=True)
y_test  = y_test.reset_index(drop=True)

# Carry out feature scaling
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = pd.DataFrame(sc.fit_transform(X_train), columns=feature_names)
X_test  = pd.DataFrame(sc.transform(X_test), columns=feature_names)

# %% [markdown]
# Users are allowed to pass their own choice of prediction models as a list.
#
# It is only important that each classifier/regressor have a ``fit`` and ``predict`` call-function.
#
# scikit-learn's ``GridSearchCV`` validates each configuration of hyperparameter with a 5-fold cross validation by default.

# %%
from sklearn.model_selection import GridSearchCV

from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

myown_prediction_models = [
    GridSearchCV(
        KNeighborsClassifier(), param_grid={'n_neighbors': [3, 4, 5]},
        n_jobs=-1 # use all processors
    ),
    GridSearchCV(
        SVC(kernel="linear", random_state=42), param_grid={'C': [0.025, 1, 10]},
        n_jobs=-1 # use all processors
    ),
    GridSearchCV(
        DecisionTreeClassifier(random_state=42), param_grid={'max_depth': [3, 4, 5]},
        n_jobs=-1 # use all processors
    )
]

# Initialize agent
AgentSelector = LTFMSelector(50, pType='classification', pModels=myown_prediction_models) # If you got time, go for 1300

# %%
# Fit
doc = AgentSelector.fit(X_train, y_train, agent_neuralnetwork=None, lr=1e-5)
# Out:
# === Episode 1 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 43
# - Features selected          : 21.0
# - Accumulated reward         : -14.28
# - Prediction model           : 2
# - Prediction model #(change) : 7
#
#
# === Episode 2 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 66
# - Features selected          : 27.0
# - Accumulated reward         : -33.32
# - Prediction model           : 1
# - Prediction model #(change) : 5
#
#
# === Episode 3 === === ===
#
# Correct prediction
# True Output: 0.0 | Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 33
# - Features selected          : 18.0
# - Accumulated reward         : -13.19
# - Prediction model           : 1
# - Prediction model #(change) : 1
#
#
# === Episode 4 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 35
# - Features selected          : 18.0
# - Accumulated reward         : -14.2
# - Prediction model           : 1
# - Prediction model #(change) : 2
#
#
# === Episode 5 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 3
# - Features selected          : 1.0
# - Accumulated reward         : -0.02
# - Prediction model           : 2
# - Prediction model #(change) : 1
#
#
# === Episode 6 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 27.0
# - Accumulated reward         : -61.3
# - Prediction model           : 0
# - Prediction model #(change) : 3
#
#
# === Episode 7 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 4
# - Features selected          : 3.0
# - Accumulated reward         : -0.03
# - Prediction model           : 2
# - Prediction model #(change) : 0
#
#
# === Episode 8 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 8
# - Features selected          : 6.0
# - Accumulated reward         : -1.06
# - Prediction model           : 2
# - Prediction model #(change) : 0
#
#
# === Episode 9 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 53
# - Features selected          : 19.0
# - Accumulated reward         : -13.39
# - Prediction model           : 0
# - Prediction model #(change) : 20
#
#
# === Episode 10 === === ===
#
# Correct prediction
# True Output: 0.0 | Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 11
# - Features selected          : 7.0
# - Accumulated reward         : -0.1
# - Prediction model           : 2
# - Prediction model #(change) : 3
#
#
# === Episode 11 === === ===
#
# Incorrect prediction
# True Output: 0.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 3
# - Features selected          : 2.0
# - Accumulated reward         : -1.02
# - Prediction model           : 1
# - Prediction model #(change) : 0
#
#
# === Episode 12 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 23.0
# - Accumulated reward         : -27.64
# - Prediction model           : 1
# - Prediction model #(change) : 41
#
#
# === Episode 13 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 65
# - Features selected          : 21.0
# - Accumulated reward         : -15.49
# - Prediction model           : 1
# - Prediction model #(change) : 28
#
#
# === Episode 14 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 8
# - Features selected          : 1.0
# - Accumulated reward         : -0.07
# - Prediction model           : 0
# - Prediction model #(change) : 6
#
#
# === Episode 15 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 13
# - Features selected          : 6.0
# - Accumulated reward         : -1.11
# - Prediction model           : 1
# - Prediction model #(change) : 5
#
#
# === Episode 16 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 22.0
# - Accumulated reward         : -25.66
# - Prediction model           : 0
# - Prediction model #(change) : 44
#
#
# === Episode 17 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 25.0
# - Accumulated reward         : -13.78
# - Prediction model           : 0
# - Prediction model #(change) : 53
#
#
# === Episode 18 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 51
# - Features selected          : 17.0
# - Accumulated reward         : -13.37
# - Prediction model           : 1
# - Prediction model #(change) : 20
#
#
# === Episode 19 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 25
# - Features selected          : 8.0
# - Accumulated reward         : -4.2
# - Prediction model           : 2
# - Prediction model #(change) : 12
#
#
# === Episode 20 === === ===
#
# Correct prediction
# True Output: 0.0 | Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 27
# - Features selected          : 12.0
# - Accumulated reward         : -0.26
# - Prediction model           : 2
# - Prediction model #(change) : 14
#
#
# === Episode 21 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 18
# - Features selected          : 6.0
# - Accumulated reward         : -2.15
# - Prediction model           : 0
# - Prediction model #(change) : 9
#
#
# === Episode 22 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 20
# - Features selected          : 9.0
# - Accumulated reward         : -1.18
# - Prediction model           : 2
# - Prediction model #(change) : 9
#
#
# === Episode 23 === === ===
#
# Correct prediction
# True Output: 0.0 | Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 18.0
# - Accumulated reward         : -10.81
# - Prediction model           : 0
# - Prediction model #(change) : 63
#
#
# === Episode 24 === === ===
# Episode terminated:
# - Iterations                 : 1
# - Features selected          : 0.0
# - Accumulated reward         : -5.0
# - Prediction model           : 0
# - Prediction model #(change) : 0
#
#
# === Episode 25 === === ===
#
# Incorrect prediction
# True Output: 0.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 29
# - Features selected          : 14.0
# - Accumulated reward         : -5.24
# - Prediction model           : 2
# - Prediction model #(change) : 10
#
#
# === Episode 26 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 60
# - Features selected          : 20.0
# - Accumulated reward         : -7.52
# - Prediction model           : 1
# - Prediction model #(change) : 32
#
#
# === Episode 27 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 25
# - Features selected          : 7.0
# - Accumulated reward         : -0.24
# - Prediction model           : 1
# - Prediction model #(change) : 17
#
#
# === Episode 28 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 50
# - Features selected          : 11.0
# - Accumulated reward         : -3.46
# - Prediction model           : 2
# - Prediction model #(change) : 35
#
#
# === Episode 29 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 31
# - Features selected          : 9.0
# - Accumulated reward         : -2.28
# - Prediction model           : 0
# - Prediction model #(change) : 19
#
#
# === Episode 30 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 21.0
# - Accumulated reward         : -8.83
# - Prediction model           : 1
# - Prediction model #(change) : 62
#
#
# === Episode 31 === === ===
#
# Incorrect prediction
# True Output: 0.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 14.0
# - Accumulated reward         : -7.85
# - Prediction model           : 2
# - Prediction model #(change) : 71
#
#
# === Episode 32 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 20.0
# - Accumulated reward         : -5.86
# - Prediction model           : 0
# - Prediction model #(change) : 66
#
#
# === Episode 33 === === ===
#
# Correct prediction
# True Output: 0.0 | Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 32
# - Features selected          : 12.0
# - Accumulated reward         : -3.28
# - Prediction model           : 2
# - Prediction model #(change) : 16
#
#
# === Episode 34 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 20
# - Features selected          : 5.0
# - Accumulated reward         : -0.19
# - Prediction model           : 0
# - Prediction model #(change) : 14
#
#
# === Episode 35 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 23
# - Features selected          : 8.0
# - Accumulated reward         : -6.16
# - Prediction model           : 2
# - Prediction model #(change) : 8
#
#
# === Episode 36 === === ===
#
# Correct prediction
# True Output: 0.0 | Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 22.0
# - Accumulated reward         : -26.65
# - Prediction model           : 0
# - Prediction model #(change) : 43
#
#
# === Episode 37 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 15.0
# - Accumulated reward         : -9.82
# - Prediction model           : 0
# - Prediction model #(change) : 67
#
#
# === Episode 38 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 28
# - Features selected          : 11.0
# - Accumulated reward         : -1.26
# - Prediction model           : 1
# - Prediction model #(change) : 15
#
#
# === Episode 39 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 28
# - Features selected          : 8.0
# - Accumulated reward         : -0.27
# - Prediction model           : 0
# - Prediction model #(change) : 19
#
#
# === Episode 40 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 66
# - Features selected          : 13.0
# - Accumulated reward         : -3.62
# - Prediction model           : 0
# - Prediction model #(change) : 49
#
#
# === Episode 41 === === ===
#
# Correct prediction
# True Output: 0.0 | Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 19.0
# - Accumulated reward         : -17.74
# - Prediction model           : 2
# - Prediction model #(change) : 55
#
#
# === Episode 42 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 73
# - Features selected          : 15.0
# - Accumulated reward         : -3.69
# - Prediction model           : 0
# - Prediction model #(change) : 54
#
#
# === Episode 43 === === ===
#
# Incorrect prediction
# True Output: 1.0 | Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 16.0
# - Accumulated reward         : -9.83
# - Prediction model           : 2
# - Prediction model #(change) : 67
#
#
# === Episode 44 === === ===
#
# Correct prediction
# True Output: 0.0 | Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 76
# - Features selected          : 18.0
# - Accumulated reward         : -6.69
# - Prediction model           : 0
# - Prediction model #(change) : 51
#
#
# === Episode 45 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 51
# - Features selected          : 10.0
# - Accumulated reward         : -1.49
# - Prediction model           : 0
# - Prediction model #(change) : 39
#
#
# === Episode 46 === === ===
#
# Correct prediction
# True Output: 0.0 | Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 9
# - Features selected          : 8.0
# - Accumulated reward         : -0.08
# - Prediction model           : 0
# - Prediction model #(change) : 0
#
#
# === Episode 47 === === ===
#
# Correct prediction
# True Output: 0.0 | Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 70
# - Features selected          : 12.0
# - Accumulated reward         : -10.59
# - Prediction model           : 0
# - Prediction model #(change) : 47
#
#
# === Episode 48 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 15.0
# - Accumulated reward         : -5.86
# - Prediction model           : 0
# - Prediction model #(change) : 71
#
#
# === Episode 49 === === ===
#
# Correct prediction
# True Output: 0.0 | Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 14.0
# - Accumulated reward         : -2.89
# - Prediction model           : 0
# - Prediction model #(change) : 75
#
#
# === Episode 50 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 21
# - Features selected          : 10.0
# - Accumulated reward         : -0.2
# - Prediction model           : 0
# - Prediction model #(change) : 10

# %%
# To test the trained agent on the test dataset
y_pred, doc_test = AgentSelector.predict(X_test)
# Out:
# === Test sample 0 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 66
# - Features selected          : 13.0
# - Accumulated reward         : -5.6
# - Prediction model           : 0
# - Prediction model #(change) : 47
#
#
# === Test sample 1 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 12.0
# - Accumulated reward         : -6.85
# - Prediction model           : 2
# - Prediction model #(change) : 73
#
#
# === Test sample 2 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 14.0
# - Accumulated reward         : -2.89
# - Prediction model           : 0
# - Prediction model #(change) : 75
#
#
# === Test sample 3 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 12.0
# - Accumulated reward         : -4.87
# - Prediction model           : 2
# - Prediction model #(change) : 75
#
#
# === Test sample 4 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 9.0
# - Accumulated reward         : -1.9
# - Prediction model           : 0
# - Prediction model #(change) : 81
#
#
# === Test sample 5 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 14.0
# - Accumulated reward         : -77.14
# - Prediction model           : 2
# - Prediction model #(change) : 0
#
#
# === Test sample 6 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 12.0
# - Accumulated reward         : -1.9
# - Prediction model           : 0
# - Prediction model #(change) : 78
#
#
# === Test sample 7 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 76
# - Features selected          : 13.0
# - Accumulated reward         : -3.72
# - Prediction model           : 2
# - Prediction model #(change) : 59
#
#
# === Test sample 8 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 9.0
# - Accumulated reward         : -0.91
# - Prediction model           : 1
# - Prediction model #(change) : 82
#
#
# === Test sample 9 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 11.0
# - Accumulated reward         : -1.9
# - Prediction model           : 2
# - Prediction model #(change) : 79
#
#
# === Test sample 10 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 22
# - Features selected          : 7.0
# - Accumulated reward         : -0.21
# - Prediction model           : 0
# - Prediction model #(change) : 14
#
#
# === Test sample 11 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 15.0
# - Accumulated reward         : -3.88
# - Prediction model           : 0
# - Prediction model #(change) : 73
#
#
# === Test sample 12 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 12.0
# - Accumulated reward         : -58.33
# - Prediction model           : 0
# - Prediction model #(change) : 21
#
#
# === Test sample 13 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 11.0
# - Accumulated reward         : -2.89
# - Prediction model           : 1
# - Prediction model #(change) : 78
#
#
# === Test sample 14 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 11
# - Features selected          : 9.0
# - Accumulated reward         : -0.1
# - Prediction model           : 1
# - Prediction model #(change) : 1
#
#
# === Test sample 15 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 10.0
# - Accumulated reward         : -1.9
# - Prediction model           : 1
# - Prediction model #(change) : 80
#
#
# === Test sample 16 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 56
# - Features selected          : 10.0
# - Accumulated reward         : -25.3
# - Prediction model           : 2
# - Prediction model #(change) : 20
#
#
# === Test sample 17 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 10
# - Features selected          : 9.0
# - Accumulated reward         : -0.09
# - Prediction model           : 2
# - Prediction model #(change) : 0
#
#
# === Test sample 18 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 11.0
# - Accumulated reward         : -0.91
# - Prediction model           : 0
# - Prediction model #(change) : 80
#
#
# === Test sample 19 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 14.0
# - Accumulated reward         : -0.91
# - Prediction model           : 1
# - Prediction model #(change) : 77
#
#
# === Test sample 20 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 14.0
# - Accumulated reward         : -0.91
# - Prediction model           : 0
# - Prediction model #(change) : 77
#
#
# === Test sample 21 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 10.0
# - Accumulated reward         : -1.9
# - Prediction model           : 2
# - Prediction model #(change) : 80
#
#
# === Test sample 22 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 52
# - Features selected          : 11.0
# - Accumulated reward         : -0.51
# - Prediction model           : 1
# - Prediction model #(change) : 40
#
#
# === Test sample 23 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 35
# - Features selected          : 6.0
# - Accumulated reward         : -1.33
# - Prediction model           : 2
# - Prediction model #(change) : 27
#
#
# === Test sample 24 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 26
# - Features selected          : 6.0
# - Accumulated reward         : -0.25
# - Prediction model           : 1
# - Prediction model #(change) : 19
#
#
# === Test sample 25 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 9.0
# - Accumulated reward         : -1.9
# - Prediction model           : 2
# - Prediction model #(change) : 81
#
#
# === Test sample 26 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 12.0
# - Accumulated reward         : -1.9
# - Prediction model           : 2
# - Prediction model #(change) : 78
#
#
# === Test sample 27 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 76
# - Features selected          : 10.0
# - Accumulated reward         : -7.68
# - Prediction model           : 2
# - Prediction model #(change) : 58
#
#
# === Test sample 28 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 15.0
# - Accumulated reward         : -2.89
# - Prediction model           : 0
# - Prediction model #(change) : 74
#
#
# === Test sample 29 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 15.0
# - Accumulated reward         : -75.16
# - Prediction model           : 2
# - Prediction model #(change) : 1
#
#
# === Test sample 30 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 11.0
# - Accumulated reward         : -79.12
# - Prediction model           : 1
# - Prediction model #(change) : 1
#
#
# === Test sample 31 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 80
# - Features selected          : 13.0
# - Accumulated reward         : -0.79
# - Prediction model           : 0
# - Prediction model #(change) : 66
#
#
# === Test sample 32 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 7.0
# - Accumulated reward         : -2.89
# - Prediction model           : 2
# - Prediction model #(change) : 82
#
#
# === Test sample 33 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 7.0
# - Accumulated reward         : -1.9
# - Prediction model           : 2
# - Prediction model #(change) : 83
#
#
# === Test sample 34 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 53
# - Features selected          : 10.0
# - Accumulated reward         : -0.52
# - Prediction model           : 0
# - Prediction model #(change) : 42
#
#
# === Test sample 35 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 10.0
# - Accumulated reward         : -1.9
# - Prediction model           : 1
# - Prediction model #(change) : 80
#
#
# === Test sample 36 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 10.0
# - Accumulated reward         : -0.91
# - Prediction model           : 2
# - Prediction model #(change) : 81
#
#
# === Test sample 37 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 16.0
# - Accumulated reward         : -3.88
# - Prediction model           : 2
# - Prediction model #(change) : 72
#
#
# === Test sample 38 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 16.0
# - Accumulated reward         : -4.87
# - Prediction model           : 2
# - Prediction model #(change) : 71
#
#
# === Test sample 39 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 9.0
# - Accumulated reward         : -82.09
# - Prediction model           : 1
# - Prediction model #(change) : 0
#
#
# === Test sample 40 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 9.0
# - Accumulated reward         : -1.9
# - Prediction model           : 2
# - Prediction model #(change) : 81
#
#
# === Test sample 41 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 12.0
# - Accumulated reward         : -2.89
# - Prediction model           : 2
# - Prediction model #(change) : 77
#
#
# === Test sample 42 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 11.0
# - Accumulated reward         : -1.9
# - Prediction model           : 1
# - Prediction model #(change) : 79
#
#
# === Test sample 43 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 10.0
# - Accumulated reward         : -0.91
# - Prediction model           : 2
# - Prediction model #(change) : 81
#
#
# === Test sample 44 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 8.0
# - Accumulated reward         : -5.86
# - Prediction model           : 2
# - Prediction model #(change) : 78
#
#
# === Test sample 45 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 13.0
# - Accumulated reward         : -3.88
# - Prediction model           : 2
# - Prediction model #(change) : 75
#
#
# === Test sample 46 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 12.0
# - Accumulated reward         : -79.12
# - Prediction model           : 2
# - Prediction model #(change) : 0
#
#
# === Test sample 47 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 13.0
# - Accumulated reward         : -2.89
# - Prediction model           : 0
# - Prediction model #(change) : 76
#
#
# === Test sample 48 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 11.0
# - Accumulated reward         : -1.9
# - Prediction model           : 2
# - Prediction model #(change) : 79
#
#
# === Test sample 49 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 7.0
# - Accumulated reward         : -84.07
# - Prediction model           : 0
# - Prediction model #(change) : 0
#
#
# === Test sample 50 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 36
# - Features selected          : 13.0
# - Accumulated reward         : -0.35
# - Prediction model           : 1
# - Prediction model #(change) : 22
#
#
# === Test sample 51 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 15.0
# - Accumulated reward         : -1.9
# - Prediction model           : 1
# - Prediction model #(change) : 75
#
#
# === Test sample 52 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 10.0
# - Accumulated reward         : -0.91
# - Prediction model           : 2
# - Prediction model #(change) : 81
#
#
# === Test sample 53 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 8.0
# - Accumulated reward         : -1.9
# - Prediction model           : 0
# - Prediction model #(change) : 82
#
#
# === Test sample 54 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 8.0
# - Accumulated reward         : -0.91
# - Prediction model           : 2
# - Prediction model #(change) : 83
#
#
# === Test sample 55 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 10.0
# - Accumulated reward         : -46.45
# - Prediction model           : 0
# - Prediction model #(change) : 35
#
#
# === Test sample 56 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 7.0
# - Accumulated reward         : -0.91
# - Prediction model           : 2
# - Prediction model #(change) : 84
#
#
# === Test sample 57 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 10.0
# - Accumulated reward         : -25.66
# - Prediction model           : 0
# - Prediction model #(change) : 56
#
#
# === Test sample 58 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 10.0
# - Accumulated reward         : -0.91
# - Prediction model           : 2
# - Prediction model #(change) : 81
#
#
# === Test sample 59 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 12.0
# - Accumulated reward         : -29.62
# - Prediction model           : 0
# - Prediction model #(change) : 50
#
#
# === Test sample 60 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 10.0
# - Accumulated reward         : -8.83
# - Prediction model           : 0
# - Prediction model #(change) : 73
#
#
# === Test sample 61 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 12.0
# - Accumulated reward         : -1.9
# - Prediction model           : 0
# - Prediction model #(change) : 78
#
#
# === Test sample 62 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 13.0
# - Accumulated reward         : -0.91
# - Prediction model           : 2
# - Prediction model #(change) : 78
#
#
# === Test sample 63 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 10.0
# - Accumulated reward         : -1.9
# - Prediction model           : 2
# - Prediction model #(change) : 80
#
#
# === Test sample 64 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 12.0
# - Accumulated reward         : -2.89
# - Prediction model           : 0
# - Prediction model #(change) : 77
#
#
# === Test sample 65 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 12.0
# - Accumulated reward         : -0.91
# - Prediction model           : 2
# - Prediction model #(change) : 79
#
#
# === Test sample 66 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 50
# - Features selected          : 14.0
# - Accumulated reward         : -1.48
# - Prediction model           : 0
# - Prediction model #(change) : 34
#
#
# === Test sample 67 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 9.0
# - Accumulated reward         : -0.91
# - Prediction model           : 1
# - Prediction model #(change) : 82
#
#
# === Test sample 68 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 10
# - Features selected          : 8.0
# - Accumulated reward         : -0.09
# - Prediction model           : 0
# - Prediction model #(change) : 1
#
#
# === Test sample 69 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 8.0
# - Accumulated reward         : -83.08
# - Prediction model           : 0
# - Prediction model #(change) : 0
#
#
# === Test sample 70 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 14
# - Features selected          : 12.0
# - Accumulated reward         : -0.13
# - Prediction model           : 0
# - Prediction model #(change) : 1
#
#
# === Test sample 71 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 6.0
# - Accumulated reward         : -80.11
# - Prediction model           : 0
# - Prediction model #(change) : 5
#
#
# === Test sample 72 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 11.0
# - Accumulated reward         : -3.88
# - Prediction model           : 0
# - Prediction model #(change) : 77
#
#
# === Test sample 73 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 8.0
# - Accumulated reward         : -0.91
# - Prediction model           : 2
# - Prediction model #(change) : 83
#
#
# === Test sample 74 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 12.0
# - Accumulated reward         : -0.91
# - Prediction model           : 0
# - Prediction model #(change) : 79
#
#
# === Test sample 75 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 6.0
# - Accumulated reward         : -0.91
# - Prediction model           : 2
# - Prediction model #(change) : 85
#
#
# === Test sample 76 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 13.0
# - Accumulated reward         : -24.67
# - Prediction model           : 0
# - Prediction model #(change) : 54
#
#
# === Test sample 77 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 20
# - Features selected          : 11.0
# - Accumulated reward         : -0.19
# - Prediction model           : 2
# - Prediction model #(change) : 8
#
#
# === Test sample 78 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 15
# - Features selected          : 7.0
# - Accumulated reward         : -0.14
# - Prediction model           : 0
# - Prediction model #(change) : 7
#
#
# === Test sample 79 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 11.0
# - Accumulated reward         : -0.91
# - Prediction model           : 0
# - Prediction model #(change) : 80
#
#
# === Test sample 80 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 11.0
# - Accumulated reward         : -39.52
# - Prediction model           : 1
# - Prediction model #(change) : 41
#
#
# === Test sample 81 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 14.0
# - Accumulated reward         : -5.86
# - Prediction model           : 2
# - Prediction model #(change) : 72
#
#
# === Test sample 82 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 11.0
# - Accumulated reward         : -1.9
# - Prediction model           : 2
# - Prediction model #(change) : 79
#
#
# === Test sample 83 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 11.0
# - Accumulated reward         : -1.9
# - Prediction model           : 0
# - Prediction model #(change) : 79
#
#
# === Test sample 84 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 66
# - Features selected          : 14.0
# - Accumulated reward         : -1.64
# - Prediction model           : 0
# - Prediction model #(change) : 50
#
#
# === Test sample 85 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 12.0
# - Accumulated reward         : -1.9
# - Prediction model           : 1
# - Prediction model #(change) : 78
#
#
# === Test sample 86 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 17.0
# - Accumulated reward         : -41.5
# - Prediction model           : 1
# - Prediction model #(change) : 33
#
#
# === Test sample 87 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 7.0
# - Accumulated reward         : -0.91
# - Prediction model           : 2
# - Prediction model #(change) : 84
#
#
# === Test sample 88 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 9.0
# - Accumulated reward         : -0.91
# - Prediction model           : 2
# - Prediction model #(change) : 82
#
#
# === Test sample 89 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 11.0
# - Accumulated reward         : -80.11
# - Prediction model           : 2
# - Prediction model #(change) : 0
#
#
# === Test sample 90 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 16.0
# - Accumulated reward         : -61.3
# - Prediction model           : 0
# - Prediction model #(change) : 14
#
#
# === Test sample 91 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 8.0
# - Accumulated reward         : -83.08
# - Prediction model           : 0
# - Prediction model #(change) : 0
#
#
# === Test sample 92 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 12.0
# - Accumulated reward         : -0.91
# - Prediction model           : 2
# - Prediction model #(change) : 79
#
#
# === Test sample 93 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 48
# - Features selected          : 10.0
# - Accumulated reward         : -0.47
# - Prediction model           : 2
# - Prediction model #(change) : 37
#
#
# === Test sample 94 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 11.0
# - Accumulated reward         : -79.12
# - Prediction model           : 1
# - Prediction model #(change) : 1
#
#
# === Test sample 95 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 9.0
# - Accumulated reward         : -80.11
# - Prediction model           : 1
# - Prediction model #(change) : 2
#
#
# === Test sample 96 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 76
# - Features selected          : 14.0
# - Accumulated reward         : -0.75
# - Prediction model           : 1
# - Prediction model #(change) : 61
#
#
# === Test sample 97 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 8.0
# - Accumulated reward         : -1.9
# - Prediction model           : 2
# - Prediction model #(change) : 82
#
#
# === Test sample 98 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 11.0
# - Accumulated reward         : -0.91
# - Prediction model           : 1
# - Prediction model #(change) : 80
#
#
# === Test sample 99 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 11.0
# - Accumulated reward         : -62.29
# - Prediction model           : 1
# - Prediction model #(change) : 18
#
#
# === Test sample 100 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 8.0
# - Accumulated reward         : -0.91
# - Prediction model           : 2
# - Prediction model #(change) : 83
#
#
# === Test sample 101 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 76
# - Features selected          : 11.0
# - Accumulated reward         : -60.15
# - Prediction model           : 2
# - Prediction model #(change) : 4
#
#
# === Test sample 102 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 10.0
# - Accumulated reward         : -0.91
# - Prediction model           : 2
# - Prediction model #(change) : 81
#
#
# === Test sample 103 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 10.0
# - Accumulated reward         : -0.91
# - Prediction model           : 1
# - Prediction model #(change) : 81
#
#
# === Test sample 104 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 8.0
# - Accumulated reward         : -0.91
# - Prediction model           : 0
# - Prediction model #(change) : 83
#
#
# === Test sample 105 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 9.0
# - Accumulated reward         : -82.09
# - Prediction model           : 1
# - Prediction model #(change) : 0
#
#
# === Test sample 106 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 8.0
# - Accumulated reward         : -0.91
# - Prediction model           : 2
# - Prediction model #(change) : 83
#
#
# === Test sample 107 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 13.0
# - Accumulated reward         : -77.14
# - Prediction model           : 0
# - Prediction model #(change) : 1
#
#
# === Test sample 108 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 12.0
# - Accumulated reward         : -0.91
# - Prediction model           : 2
# - Prediction model #(change) : 79
#
#
# === Test sample 109 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 82
# - Features selected          : 12.0
# - Accumulated reward         : -0.81
# - Prediction model           : 2
# - Prediction model #(change) : 69
#
#
# === Test sample 110 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 12.0
# - Accumulated reward         : -2.89
# - Prediction model           : 1
# - Prediction model #(change) : 77
#
#
# === Test sample 111 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 9.0
# - Accumulated reward         : -1.9
# - Prediction model           : 1
# - Prediction model #(change) : 81
#
#
# === Test sample 112 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 4
# - Features selected          : 3.0
# - Accumulated reward         : -0.03
# - Prediction model           : 0
# - Prediction model #(change) : 0
#
#
# === Test sample 113 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 8.0
# - Accumulated reward         : -1.9
# - Prediction model           : 0
# - Prediction model #(change) : 82

# %%
# Let's check out the classification accuracy
from sklearn.metrics import accuracy_score

acc = accuracy_score(y_test, y_pred)
print(f"Accuracy: {acc}")
# Out:
# Accuracy: 0.9385964912280702
