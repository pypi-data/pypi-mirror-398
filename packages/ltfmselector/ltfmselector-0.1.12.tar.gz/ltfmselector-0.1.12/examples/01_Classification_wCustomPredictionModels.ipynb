# %% [markdown]
# ## Using Your Own Prediction Models for Classification
#
# Just like in [classification.ipynb](./classification.ipynb), we will use the UCI ML Breast Cancer Wisconsin dataset again.

# %%
from ltfmselector import LTFMSelector

import numpy as np
import pandas as pd
from sklearn.datasets import load_breast_cancer

# %% [markdown]
# Pre-processing the datasets

# %%
# Load breast cancer dataset
cancer_dataset = load_breast_cancer()

# Get data
X = cancer_dataset['data']

# Get target
y = cancer_dataset['target']
# - 0: malignant tumor
# - 1: benign tumor

# Get feature names
feature_names = cancer_dataset['feature_names']

# Get description
dataset_description = cancer_dataset['DESCR']

# Convert data into pandas DataFrame
cancer_df = pd.DataFrame(
    np.c_[X, y], columns = np.append(feature_names, ['target'])
)

# Split the dataset for training and test
X_df = cancer_df.drop(['target'], axis=1)
y_df = cancer_df['target']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_df, y_df, test_size=0.2, random_state=5)

y_train = y_train.reset_index(drop=True)
y_test  = y_test.reset_index(drop=True)

# Carry out feature scaling
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = pd.DataFrame(sc.fit_transform(X_train), columns=feature_names)
X_test  = pd.DataFrame(sc.transform(X_test), columns=feature_names)

# %% [markdown]
# Users are allowed to pass their own choice of prediction models as a list.
#
# It is only important that each classifier/regressor have a ``fit`` and ``predict`` call-function.

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

myown_prediction_models = [
    AdaBoostClassifier(random_state=42),
    KNeighborsClassifier(3),
    LinearDiscriminantAnalysis(),
    SVC(kernel="linear", C=0.025, random_state=42),
    DecisionTreeClassifier(max_depth=5, random_state=42)
]

# Initialize agent
AgentSelector = LTFMSelector(50, pType='classification', pModels=myown_prediction_models) # If you got time, go for 1300

# %%
# Fit
doc = AgentSelector.fit(X_train, y_train, agent_neuralnetwork=None, lr=1e-5)
# Out:
# === Episode 1 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 43
# - Features selected          : 17.0
# - Accumulated reward         : -17.25
# - Prediction model           : 0
# - Prediction model #(change) : 8
#
#
# === Episode 2 === === ===
#
# Correct prediction
# True Output: 0.0 | Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 9
# - Features selected          : 6.0
# - Accumulated reward         : -1.07
# - Prediction model           : 2
# - Prediction model #(change) : 1
#
#
# === Episode 3 === === ===
#
# Correct prediction
# True Output: 0.0 | Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 25.0
# - Accumulated reward         : -39.52
# - Prediction model           : 4
# - Prediction model #(change) : 27
#
#
# === Episode 4 === === ===
#
# Incorrect prediction
# True Output: 1.0 | Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 5
# - Features selected          : 2.0
# - Accumulated reward         : -1.04
# - Prediction model           : 1
# - Prediction model #(change) : 2
#
#
# === Episode 5 === === ===
#
# Correct prediction
# True Output: 0.0 | Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 17
# - Features selected          : 13.0
# - Accumulated reward         : -3.13
# - Prediction model           : 4
# - Prediction model #(change) : 0
#
#
# === Episode 6 === === ===
#
# Incorrect prediction
# True Output: 0.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 35
# - Features selected          : 18.0
# - Accumulated reward         : -7.28
# - Prediction model           : 3
# - Prediction model #(change) : 10
#
#
# === Episode 7 === === ===
#
# Correct prediction
# True Output: 0.0 | Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 23.0
# - Accumulated reward         : -52.39
# - Prediction model           : 4
# - Prediction model #(change) : 16
#
#
# === Episode 8 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 83
# - Features selected          : 23.0
# - Accumulated reward         : -23.59
# - Prediction model           : 2
# - Prediction model #(change) : 36
#
#
# === Episode 9 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 80
# - Features selected          : 19.0
# - Accumulated reward         : -25.54
# - Prediction model           : 3
# - Prediction model #(change) : 35
#
#
# === Episode 10 === === ===
#
# Correct prediction
# True Output: 0.0 | Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 70
# - Features selected          : 19.0
# - Accumulated reward         : -15.54
# - Prediction model           : 3
# - Prediction model #(change) : 35
#
#
# === Episode 11 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 18
# - Features selected          : 9.0
# - Accumulated reward         : -0.17
# - Prediction model           : 4
# - Prediction model #(change) : 8
#
#
# === Episode 12 === === ===
#
# Correct prediction
# True Output: 0.0 | Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 23.0
# - Accumulated reward         : -24.67
# - Prediction model           : 4
# - Prediction model #(change) : 44
#
#
# === Episode 13 === === ===
#
# Correct prediction
# True Output: 0.0 | Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 26.0
# - Accumulated reward         : -21.7
# - Prediction model           : 4
# - Prediction model #(change) : 44
#
#
# === Episode 14 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 84
# - Features selected          : 15.0
# - Accumulated reward         : -13.7
# - Prediction model           : 4
# - Prediction model #(change) : 55
#
#
# === Episode 15 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 20.0
# - Accumulated reward         : -16.75
# - Prediction model           : 2
# - Prediction model #(change) : 55
#
#
# === Episode 16 === === ===
#
# Correct prediction
# True Output: 0.0 | Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 48
# - Features selected          : 12.0
# - Accumulated reward         : -6.41
# - Prediction model           : 0
# - Prediction model #(change) : 29
#
#
# === Episode 17 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 71
# - Features selected          : 14.0
# - Accumulated reward         : -9.61
# - Prediction model           : 0
# - Prediction model #(change) : 47
#
#
# === Episode 18 === === ===
#
# Correct prediction
# True Output: 0.0 | Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 77
# - Features selected          : 17.0
# - Accumulated reward         : -7.69
# - Prediction model           : 3
# - Prediction model #(change) : 52
#
#
# === Episode 19 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 39
# - Features selected          : 10.0
# - Accumulated reward         : -2.36
# - Prediction model           : 2
# - Prediction model #(change) : 26
#
#
# === Episode 20 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 89
# - Features selected          : 17.0
# - Accumulated reward         : -14.74
# - Prediction model           : 4
# - Prediction model #(change) : 57
#
#
# === Episode 21 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 18.0
# - Accumulated reward         : -10.81
# - Prediction model           : 3
# - Prediction model #(change) : 63
#
#
# === Episode 22 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 21.0
# - Accumulated reward         : -7.84
# - Prediction model           : 4
# - Prediction model #(change) : 63
#
#
# === Episode 23 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 15.0
# - Accumulated reward         : -9.82
# - Prediction model           : 1
# - Prediction model #(change) : 67
#
#
# === Episode 24 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 4
# - Features selected          : 2.0
# - Accumulated reward         : -0.03
# - Prediction model           : 4
# - Prediction model #(change) : 1
#
#
# === Episode 25 === === ===
# Episode terminated:
# - Iterations                 : 1
# - Features selected          : 0.0
# - Accumulated reward         : -5.0
# - Prediction model           : 4
# - Prediction model #(change) : 0
#
#
# === Episode 26 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 26
# - Features selected          : 11.0
# - Accumulated reward         : -6.19
# - Prediction model           : 3
# - Prediction model #(change) : 8
#
#
# === Episode 27 === === ===
#
# Correct prediction
# True Output: 0.0 | Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 16.0
# - Accumulated reward         : -8.83
# - Prediction model           : 0
# - Prediction model #(change) : 67
#
#
# === Episode 28 === === ===
#
# Correct prediction
# True Output: 0.0 | Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 12
# - Features selected          : 5.0
# - Accumulated reward         : -0.11
# - Prediction model           : 3
# - Prediction model #(change) : 6
#
#
# === Episode 29 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 16.0
# - Accumulated reward         : -9.82
# - Prediction model           : 4
# - Prediction model #(change) : 66
#
#
# === Episode 30 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 12.0
# - Accumulated reward         : -1.9
# - Prediction model           : 3
# - Prediction model #(change) : 78
#
#
# === Episode 31 === === ===
#
# Incorrect prediction
# True Output: 0.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 17.0
# - Accumulated reward         : -5.87
# - Prediction model           : 4
# - Prediction model #(change) : 70
#
#
# === Episode 32 === === ===
#
# Correct prediction
# True Output: 0.0 | Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 15.0
# - Accumulated reward         : -3.88
# - Prediction model           : 4
# - Prediction model #(change) : 73
#
#
# === Episode 33 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 60
# - Features selected          : 10.0
# - Accumulated reward         : -0.59
# - Prediction model           : 1
# - Prediction model #(change) : 49
#
#
# === Episode 34 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 88
# - Features selected          : 14.0
# - Accumulated reward         : -11.76
# - Prediction model           : 4
# - Prediction model #(change) : 62
#
#
# === Episode 35 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 18.0
# - Accumulated reward         : -5.86
# - Prediction model           : 1
# - Prediction model #(change) : 68
#
#
# === Episode 36 === === ===
#
# Correct prediction
# True Output: 0.0 | Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 11.0
# - Accumulated reward         : -15.76
# - Prediction model           : 4
# - Prediction model #(change) : 65
#
#
# === Episode 37 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 12.0
# - Accumulated reward         : -3.88
# - Prediction model           : 4
# - Prediction model #(change) : 76
#
#
# === Episode 38 === === ===
#
# Incorrect prediction
# True Output: 0.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 11.0
# - Accumulated reward         : -5.87
# - Prediction model           : 1
# - Prediction model #(change) : 76
#
#
# === Episode 39 === === ===
#
# Correct prediction
# True Output: 0.0 | Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 11.0
# - Accumulated reward         : -6.85
# - Prediction model           : 2
# - Prediction model #(change) : 74
#
#
# === Episode 40 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 15.0
# - Accumulated reward         : -3.88
# - Prediction model           : 4
# - Prediction model #(change) : 73
#
#
# === Episode 41 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 16.0
# - Accumulated reward         : -2.89
# - Prediction model           : 2
# - Prediction model #(change) : 73
#
#
# === Episode 42 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 17.0
# - Accumulated reward         : -1.9
# - Prediction model           : 2
# - Prediction model #(change) : 73
#
#
# === Episode 43 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 10.0
# - Accumulated reward         : -0.91
# - Prediction model           : 4
# - Prediction model #(change) : 81
#
#
# === Episode 44 === === ===
#
# Correct prediction
# True Output: 0.0 | Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 11.0
# - Accumulated reward         : -1.9
# - Prediction model           : 3
# - Prediction model #(change) : 79
#
#
# === Episode 45 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 21
# - Features selected          : 11.0
# - Accumulated reward         : -0.2
# - Prediction model           : 0
# - Prediction model #(change) : 9
#
#
# === Episode 46 === === ===
#
# Correct prediction
# True Output: 0.0 | Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 12.0
# - Accumulated reward         : -2.89
# - Prediction model           : 3
# - Prediction model #(change) : 77
#
#
# === Episode 47 === === ===
#
# Correct prediction
# True Output: 0.0 | Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 13.0
# - Accumulated reward         : -2.89
# - Prediction model           : 4
# - Prediction model #(change) : 76
#
#
# === Episode 48 === === ===
#
# Correct prediction
# True Output: 0.0 | Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 80
# - Features selected          : 8.0
# - Accumulated reward         : -2.77
# - Prediction model           : 1
# - Prediction model #(change) : 69
#
#
# === Episode 49 === === ===
#
# Correct prediction
# True Output: 1.0 | Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 13.0
# - Accumulated reward         : -0.91
# - Prediction model           : 2
# - Prediction model #(change) : 78
#
#
# === Episode 50 === === ===
#
# Incorrect prediction
# True Output: 1.0 | Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 2
# - Features selected          : 1.0
# - Accumulated reward         : -1.01
# - Prediction model           : 1
# - Prediction model #(change) : 0

# %%
# To test the trained agent on the test dataset
y_pred, doc_test = AgentSelector.predict(X_test)
# Out:
# === Test sample 0 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 12.0
# - Accumulated reward         : -1.9
# - Prediction model           : 4
# - Prediction model #(change) : 78
#
#
# === Test sample 1 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 9.0
# - Accumulated reward         : -4.87
# - Prediction model           : 2
# - Prediction model #(change) : 78
#
#
# === Test sample 2 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 15.0
# - Accumulated reward         : -5.86
# - Prediction model           : 1
# - Prediction model #(change) : 71
#
#
# === Test sample 3 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 18
# - Features selected          : 12.0
# - Accumulated reward         : -0.17
# - Prediction model           : 1
# - Prediction model #(change) : 5
#
#
# === Test sample 4 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 12.0
# - Accumulated reward         : -1.9
# - Prediction model           : 3
# - Prediction model #(change) : 78
#
#
# === Test sample 5 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 9.0
# - Accumulated reward         : -0.91
# - Prediction model           : 4
# - Prediction model #(change) : 82
#
#
# === Test sample 6 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 9.0
# - Accumulated reward         : -0.91
# - Prediction model           : 2
# - Prediction model #(change) : 82
#
#
# === Test sample 7 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 9.0
# - Accumulated reward         : -0.91
# - Prediction model           : 4
# - Prediction model #(change) : 82
#
#
# === Test sample 8 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 12.0
# - Accumulated reward         : -1.9
# - Prediction model           : 4
# - Prediction model #(change) : 78
#
#
# === Test sample 9 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 8.0
# - Accumulated reward         : -1.9
# - Prediction model           : 4
# - Prediction model #(change) : 82
#
#
# === Test sample 10 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 12.0
# - Accumulated reward         : -1.9
# - Prediction model           : 1
# - Prediction model #(change) : 78
#
#
# === Test sample 11 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 10.0
# - Accumulated reward         : -3.88
# - Prediction model           : 3
# - Prediction model #(change) : 78
#
#
# === Test sample 12 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 7.0
# - Accumulated reward         : -1.9
# - Prediction model           : 4
# - Prediction model #(change) : 83
#
#
# === Test sample 13 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 13.0
# - Accumulated reward         : -1.9
# - Prediction model           : 4
# - Prediction model #(change) : 77
#
#
# === Test sample 14 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 11.0
# - Accumulated reward         : -2.89
# - Prediction model           : 3
# - Prediction model #(change) : 78
#
#
# === Test sample 15 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 13.0
# - Accumulated reward         : -2.89
# - Prediction model           : 3
# - Prediction model #(change) : 76
#
#
# === Test sample 16 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 13.0
# - Accumulated reward         : -3.88
# - Prediction model           : 3
# - Prediction model #(change) : 75
#
#
# === Test sample 17 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 7.0
# - Accumulated reward         : -0.91
# - Prediction model           : 4
# - Prediction model #(change) : 84
#
#
# === Test sample 18 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 14.0
# - Accumulated reward         : -3.88
# - Prediction model           : 4
# - Prediction model #(change) : 74
#
#
# === Test sample 19 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 12
# - Features selected          : 9.0
# - Accumulated reward         : -0.11
# - Prediction model           : 4
# - Prediction model #(change) : 2
#
#
# === Test sample 20 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 11.0
# - Accumulated reward         : -1.9
# - Prediction model           : 4
# - Prediction model #(change) : 79
#
#
# === Test sample 21 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 11.0
# - Accumulated reward         : -2.89
# - Prediction model           : 4
# - Prediction model #(change) : 78
#
#
# === Test sample 22 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 6.0
# - Accumulated reward         : -1.9
# - Prediction model           : 4
# - Prediction model #(change) : 84
#
#
# === Test sample 23 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 10.0
# - Accumulated reward         : -2.89
# - Prediction model           : 4
# - Prediction model #(change) : 79
#
#
# === Test sample 24 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 10.0
# - Accumulated reward         : -2.89
# - Prediction model           : 4
# - Prediction model #(change) : 79
#
#
# === Test sample 25 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 11.0
# - Accumulated reward         : -0.91
# - Prediction model           : 4
# - Prediction model #(change) : 80
#
#
# === Test sample 26 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 10.0
# - Accumulated reward         : -0.91
# - Prediction model           : 1
# - Prediction model #(change) : 81
#
#
# === Test sample 27 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 7.0
# - Accumulated reward         : -1.9
# - Prediction model           : 4
# - Prediction model #(change) : 83
#
#
# === Test sample 28 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 7.0
# - Accumulated reward         : -0.91
# - Prediction model           : 1
# - Prediction model #(change) : 84
#
#
# === Test sample 29 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 34
# - Features selected          : 6.0
# - Accumulated reward         : -0.33
# - Prediction model           : 4
# - Prediction model #(change) : 27
#
#
# === Test sample 30 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 88
# - Features selected          : 8.0
# - Accumulated reward         : -4.83
# - Prediction model           : 1
# - Prediction model #(change) : 75
#
#
# === Test sample 31 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 11.0
# - Accumulated reward         : -0.91
# - Prediction model           : 4
# - Prediction model #(change) : 80
#
#
# === Test sample 32 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 16.0
# - Accumulated reward         : -2.89
# - Prediction model           : 3
# - Prediction model #(change) : 73
#
#
# === Test sample 33 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 21
# - Features selected          : 5.0
# - Accumulated reward         : -0.2
# - Prediction model           : 4
# - Prediction model #(change) : 15
#
#
# === Test sample 34 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 9.0
# - Accumulated reward         : -1.9
# - Prediction model           : 4
# - Prediction model #(change) : 81
#
#
# === Test sample 35 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 12.0
# - Accumulated reward         : -1.9
# - Prediction model           : 0
# - Prediction model #(change) : 78
#
#
# === Test sample 36 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 5.0
# - Accumulated reward         : -0.91
# - Prediction model           : 3
# - Prediction model #(change) : 86
#
#
# === Test sample 37 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 8.0
# - Accumulated reward         : -1.9
# - Prediction model           : 4
# - Prediction model #(change) : 82
#
#
# === Test sample 38 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 11.0
# - Accumulated reward         : -1.9
# - Prediction model           : 4
# - Prediction model #(change) : 79
#
#
# === Test sample 39 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 11.0
# - Accumulated reward         : -33.58
# - Prediction model           : 3
# - Prediction model #(change) : 47
#
#
# === Test sample 40 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 77
# - Features selected          : 15.0
# - Accumulated reward         : -1.75
# - Prediction model           : 2
# - Prediction model #(change) : 60
#
#
# === Test sample 41 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 6.0
# - Accumulated reward         : -3.88
# - Prediction model           : 4
# - Prediction model #(change) : 82
#
#
# === Test sample 42 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 14.0
# - Accumulated reward         : -59.32
# - Prediction model           : 1
# - Prediction model #(change) : 18
#
#
# === Test sample 43 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 10.0
# - Accumulated reward         : -1.9
# - Prediction model           : 1
# - Prediction model #(change) : 80
#
#
# === Test sample 44 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 11
# - Features selected          : 7.0
# - Accumulated reward         : -0.1
# - Prediction model           : 4
# - Prediction model #(change) : 3
#
#
# === Test sample 45 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 8.0
# - Accumulated reward         : -0.91
# - Prediction model           : 4
# - Prediction model #(change) : 83
#
#
# === Test sample 46 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 14.0
# - Accumulated reward         : -1.9
# - Prediction model           : 3
# - Prediction model #(change) : 76
#
#
# === Test sample 47 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 13.0
# - Accumulated reward         : -0.91
# - Prediction model           : 2
# - Prediction model #(change) : 78
#
#
# === Test sample 48 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 75
# - Features selected          : 8.0
# - Accumulated reward         : -3.71
# - Prediction model           : 2
# - Prediction model #(change) : 63
#
#
# === Test sample 49 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 6.0
# - Accumulated reward         : -85.06
# - Prediction model           : 2
# - Prediction model #(change) : 0
#
#
# === Test sample 50 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 14.0
# - Accumulated reward         : -55.36
# - Prediction model           : 4
# - Prediction model #(change) : 22
#
#
# === Test sample 51 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 14.0
# - Accumulated reward         : -2.89
# - Prediction model           : 2
# - Prediction model #(change) : 75
#
#
# === Test sample 52 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 83
# - Features selected          : 10.0
# - Accumulated reward         : -3.79
# - Prediction model           : 4
# - Prediction model #(change) : 69
#
#
# === Test sample 53 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 11.0
# - Accumulated reward         : -0.91
# - Prediction model           : 4
# - Prediction model #(change) : 80
#
#
# === Test sample 54 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 11.0
# - Accumulated reward         : -2.89
# - Prediction model           : 1
# - Prediction model #(change) : 78
#
#
# === Test sample 55 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 5
# - Features selected          : 4.0
# - Accumulated reward         : -0.04
# - Prediction model           : 2
# - Prediction model #(change) : 0
#
#
# === Test sample 56 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 73
# - Features selected          : 10.0
# - Accumulated reward         : -1.71
# - Prediction model           : 3
# - Prediction model #(change) : 61
#
#
# === Test sample 57 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 14.0
# - Accumulated reward         : -0.91
# - Prediction model           : 1
# - Prediction model #(change) : 77
#
#
# === Test sample 58 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 9.0
# - Accumulated reward         : -1.9
# - Prediction model           : 4
# - Prediction model #(change) : 81
#
#
# === Test sample 59 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 8.0
# - Accumulated reward         : -2.89
# - Prediction model           : 4
# - Prediction model #(change) : 81
#
#
# === Test sample 60 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 44
# - Features selected          : 13.0
# - Accumulated reward         : -0.43
# - Prediction model           : 1
# - Prediction model #(change) : 30
#
#
# === Test sample 61 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 8.0
# - Accumulated reward         : -3.88
# - Prediction model           : 3
# - Prediction model #(change) : 80
#
#
# === Test sample 62 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 17.0
# - Accumulated reward         : -2.89
# - Prediction model           : 4
# - Prediction model #(change) : 72
#
#
# === Test sample 63 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 49
# - Features selected          : 7.0
# - Accumulated reward         : -1.47
# - Prediction model           : 4
# - Prediction model #(change) : 40
#
#
# === Test sample 64 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 27
# - Features selected          : 8.0
# - Accumulated reward         : -0.26
# - Prediction model           : 4
# - Prediction model #(change) : 18
#
#
# === Test sample 65 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 9.0
# - Accumulated reward         : -2.89
# - Prediction model           : 0
# - Prediction model #(change) : 80
#
#
# === Test sample 66 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 7.0
# - Accumulated reward         : -2.89
# - Prediction model           : 4
# - Prediction model #(change) : 82
#
#
# === Test sample 67 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 81
# - Features selected          : 6.0
# - Accumulated reward         : -0.8
# - Prediction model           : 1
# - Prediction model #(change) : 74
#
#
# === Test sample 68 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 13.0
# - Accumulated reward         : -0.91
# - Prediction model           : 1
# - Prediction model #(change) : 78
#
#
# === Test sample 69 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 11.0
# - Accumulated reward         : -1.9
# - Prediction model           : 4
# - Prediction model #(change) : 79
#
#
# === Test sample 70 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 4.0
# - Accumulated reward         : -0.91
# - Prediction model           : 0
# - Prediction model #(change) : 87
#
#
# === Test sample 71 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 12.0
# - Accumulated reward         : -0.91
# - Prediction model           : 4
# - Prediction model #(change) : 79
#
#
# === Test sample 72 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 10.0
# - Accumulated reward         : -1.9
# - Prediction model           : 2
# - Prediction model #(change) : 80
#
#
# === Test sample 73 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 10.0
# - Accumulated reward         : -0.91
# - Prediction model           : 1
# - Prediction model #(change) : 81
#
#
# === Test sample 74 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 4.0
# - Accumulated reward         : -2.89
# - Prediction model           : 4
# - Prediction model #(change) : 85
#
#
# === Test sample 75 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 10.0
# - Accumulated reward         : -5.86
# - Prediction model           : 4
# - Prediction model #(change) : 76
#
#
# === Test sample 76 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 12.0
# - Accumulated reward         : -1.9
# - Prediction model           : 3
# - Prediction model #(change) : 78
#
#
# === Test sample 77 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 33
# - Features selected          : 10.0
# - Accumulated reward         : -0.32
# - Prediction model           : 1
# - Prediction model #(change) : 22
#
#
# === Test sample 78 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 10.0
# - Accumulated reward         : -2.89
# - Prediction model           : 4
# - Prediction model #(change) : 79
#
#
# === Test sample 79 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 15.0
# - Accumulated reward         : -2.89
# - Prediction model           : 1
# - Prediction model #(change) : 74
#
#
# === Test sample 80 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 13.0
# - Accumulated reward         : -63.28
# - Prediction model           : 4
# - Prediction model #(change) : 15
#
#
# === Test sample 81 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 8.0
# - Accumulated reward         : -0.91
# - Prediction model           : 4
# - Prediction model #(change) : 83
#
#
# === Test sample 82 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 13.0
# - Accumulated reward         : -2.89
# - Prediction model           : 4
# - Prediction model #(change) : 76
#
#
# === Test sample 83 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 11.0
# - Accumulated reward         : -0.91
# - Prediction model           : 3
# - Prediction model #(change) : 80
#
#
# === Test sample 84 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 10.0
# - Accumulated reward         : -1.9
# - Prediction model           : 3
# - Prediction model #(change) : 80
#
#
# === Test sample 85 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 17.0
# - Accumulated reward         : -0.91
# - Prediction model           : 4
# - Prediction model #(change) : 74
#
#
# === Test sample 86 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 10.0
# - Accumulated reward         : -2.89
# - Prediction model           : 2
# - Prediction model #(change) : 79
#
#
# === Test sample 87 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 29
# - Features selected          : 7.0
# - Accumulated reward         : -0.28
# - Prediction model           : 4
# - Prediction model #(change) : 21
#
#
# === Test sample 88 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 13.0
# - Accumulated reward         : -55.36
# - Prediction model           : 0
# - Prediction model #(change) : 23
#
#
# === Test sample 89 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 9.0
# - Accumulated reward         : -2.89
# - Prediction model           : 2
# - Prediction model #(change) : 80
#
#
# === Test sample 90 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 9.0
# - Accumulated reward         : -1.9
# - Prediction model           : 4
# - Prediction model #(change) : 81
#
#
# === Test sample 91 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 10.0
# - Accumulated reward         : -0.91
# - Prediction model           : 3
# - Prediction model #(change) : 81
#
#
# === Test sample 92 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 13.0
# - Accumulated reward         : -0.91
# - Prediction model           : 1
# - Prediction model #(change) : 78
#
#
# === Test sample 93 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 11.0
# - Accumulated reward         : -1.9
# - Prediction model           : 4
# - Prediction model #(change) : 79
#
#
# === Test sample 94 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 11.0
# - Accumulated reward         : -0.91
# - Prediction model           : 3
# - Prediction model #(change) : 80
#
#
# === Test sample 95 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 15
# - Features selected          : 5.0
# - Accumulated reward         : -9.05
# - Prediction model           : 3
# - Prediction model #(change) : 0
#
#
# === Test sample 96 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 17.0
# - Accumulated reward         : -1.9
# - Prediction model           : 1
# - Prediction model #(change) : 73
#
#
# === Test sample 97 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 11.0
# - Accumulated reward         : -1.9
# - Prediction model           : 4
# - Prediction model #(change) : 79
#
#
# === Test sample 98 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 12.0
# - Accumulated reward         : -8.83
# - Prediction model           : 4
# - Prediction model #(change) : 71
#
#
# === Test sample 99 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 12.0
# - Accumulated reward         : -0.91
# - Prediction model           : 4
# - Prediction model #(change) : 79
#
#
# === Test sample 100 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 14.0
# - Accumulated reward         : -32.59
# - Prediction model           : 0
# - Prediction model #(change) : 45
#
#
# === Test sample 101 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 6
# - Features selected          : 4.0
# - Accumulated reward         : -0.05
# - Prediction model           : 0
# - Prediction model #(change) : 1
#
#
# === Test sample 102 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 3
# - Features selected          : 2.0
# - Accumulated reward         : -0.02
# - Prediction model           : 0
# - Prediction model #(change) : 0
#
#
# === Test sample 103 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 11.0
# - Accumulated reward         : -1.9
# - Prediction model           : 1
# - Prediction model #(change) : 79
#
#
# === Test sample 104 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 9.0
# - Accumulated reward         : -0.91
# - Prediction model           : 4
# - Prediction model #(change) : 82
#
#
# === Test sample 105 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 11.0
# - Accumulated reward         : -1.9
# - Prediction model           : 4
# - Prediction model #(change) : 79
#
#
# === Test sample 106 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 54
# - Features selected          : 11.0
# - Accumulated reward         : -1.52
# - Prediction model           : 0
# - Prediction model #(change) : 41
#
#
# === Test sample 107 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 10.0
# - Accumulated reward         : -0.91
# - Prediction model           : 4
# - Prediction model #(change) : 81
#
#
# === Test sample 108 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 9.0
# - Accumulated reward         : -1.9
# - Prediction model           : 4
# - Prediction model #(change) : 81
#
#
# === Test sample 109 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 15.0
# - Accumulated reward         : -0.91
# - Prediction model           : 4
# - Prediction model #(change) : 76
#
#
# === Test sample 110 === === ===
# Prediction: 1.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 10.0
# - Accumulated reward         : -3.88
# - Prediction model           : 4
# - Prediction model #(change) : 78
#
#
# === Test sample 111 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 9.0
# - Accumulated reward         : -1.9
# - Prediction model           : 2
# - Prediction model #(change) : 81
#
#
# === Test sample 112 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 14.0
# - Accumulated reward         : -1.9
# - Prediction model           : 4
# - Prediction model #(change) : 76
#
#
# === Test sample 113 === === ===
# Prediction: 0.0
#
# Episode terminated:
# - Iterations                 : 92
# - Features selected          : 14.0
# - Accumulated reward         : -0.91
# - Prediction model           : 4
# - Prediction model #(change) : 77

# %%
# Let's check out the classification accuracy
from sklearn.metrics import accuracy_score

acc = accuracy_score(y_test, y_pred)
print(f"Accuracy: {acc}")
# Out:
# Accuracy: 0.9473684210526315
