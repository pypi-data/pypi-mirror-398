# %% [markdown]
# ## Load the extension

# %%
# %load_ext autoreload
# %aimport -sparkmagic # it loses the references to the sessions if it reloads
# %autoreload 2

# %%
# %reload_ext livy_uploads.magics

# %% [markdown]
# ## Configuring the local session

# %% [markdown]
# #### Configuring logging

# %%
# %%local
#
# import logging
#
#
# LOGGER = logging.getLogger(__name__)
# LOGGER.info('gone to the black hole')
#
# %configure_logging
#
# LOGGER.info('now we can see at least this one')
# Out:
# 2025-12-21 15:35:47 [INFO] __main__: now we can see at least this one

# %% [markdown]
# #### Loading env files

# %%
# %dotenv
# Out:
# 2025-12-21 15:35:48 [INFO] livy_uploads.paths: loading envfile from /app/.env
# 2025-12-21 15:35:48 [INFO] livy_uploads.paths: setting 2 environment variables: $USER_UID, $USER_GID

# %%
# %dotenv env.empty
# Out:
# 2025-12-21 15:35:49 [INFO] livy_uploads.paths: loading envfile from /app/env.empty
# 2025-12-21 15:35:49 [INFO] livy_uploads.paths: no environment variables to set from /app/env.empty

# %% [markdown]
# #### Resolving notebooks

# %%
# %nblib hostinfo.ipynb
# Out:
# 2025-12-21 15:35:49 [INFO] livy_uploads.paths: setting NBLIB_PATH='/app/livy_uploads'
# 2025-12-21 15:35:49 [WARNING] livy_uploads.magics: resolved %run hostinfo.ipynb to /app/livy_uploads/hostinfo.ipynb
# {'now': '2025-12-21T15:35:50.810404+00:00',
#  'host': 'eb034981a6cc',
#  'pyspark_version': '3.3.2',
#  'scala_version': '<not available>'}

# %% [markdown]
# ## Configuring the remote session

# %% [markdown]
# #### Resolving notebooks with `%%spark`

# %%
# %nblib spark/hostinfo.ipynb
# Out:
# 2025-12-21 15:35:53 [WARNING] livy_uploads.magics: resolved %run spark/hostinfo.ipynb to /app/livy_uploads/spark/hostinfo.ipynb
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>User</th><th>Current session?</th></tr><tr><td>2</td><td>application_1766330690133_0003</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://resourcemanager.localhost:8088/proxy/application_1766330690133_0003/">Link</a></td><td><a target="_blank" href="http://nodemanager1.localhost:8041/node/containerlogs/container_1766330690133_0003_01_000001/root">Link</a></td><td>None</td><td>✔</td></tr></table>
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# {'now': '2025-12-21T15:36:27.287003+00:00',
#  'host': 'nodemanager1.localhost',
#  'pyspark_version': '3.3.2',
#  'scala_version': 'version 2.12.15'}

# %% [markdown]
# #### Fetching remote variable

# %%
# %%local
#
# try:
#     del remote_info
# except Exception:
#     pass

# %%
import socket

remote_info = {'now': datetime.now().astimezone(), 'hostname': socket.getfqdn()}
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# %get_obj_from_spark -n remote_info

print('remote_info:', remote_info)
assert 'nodemanager' in remote_info['hostname']
# Out:
# remote_info: {'now': datetime.datetime(2025, 12, 21, 15, 36, 27, 546409, tzinfo=datetime.timezone(datetime.timedelta(0), 'UTC')), 'hostname': 'nodemanager1.localhost'}

# %% [markdown]
# #### Sending local variable

# %%
try:
    del local_info
except Exception:
    pass
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
# %%local
#
# import socket
#
# local_info = {'now': datetime.now().astimezone(), 'hostname': socket.getfqdn()}
#
# %send_obj_to_spark -n local_info

# %%
print('local_info:', local_info)
assert 'nodemanager' not in local_info['hostname']
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# local_info: {'now': datetime.datetime(2025, 12, 21, 15, 36, 27, 663805, tzinfo=datetime.timezone(datetime.timedelta(0), 'UTC')), 'hostname': 'eb034981a6cc'}

# %% [markdown]
# #### Running shell commands

# %%
# %%shell_command
#
# ls -lahF . | head -n 15
# Out:
# total 208K
# drwx--x--- 3 root root 4.0K Dec 21 15:36 ./
# drwx--x--- 8 root root 4.0K Dec 21 15:36 ../
# -rw-r--r-- 1 root root   12 Dec 21 15:36 .container_tokens.crc
# -rw-r--r-- 1 root root   16 Dec 21 15:36 .default_container_executor.sh.crc
# -rw-r--r-- 1 root root   16 Dec 21 15:36 .default_container_executor_session.sh.crc
# -rw-r--r-- 1 root root  104 Dec 21 15:36 .launch_container.sh.crc
# lrwxrwxrwx 1 root root   52 Dec 21 15:36 __spark_conf__ -> /tmp/usercache/root/filecache/131/__spark_conf__.zip/
# lrwxrwxrwx 1 root root   71 Dec 21 15:36 __spark_libs__ -> /tmp/usercache/root/filecache/117/__spark_libs__1464618954637771830.zip/
# lrwxrwxrwx 1 root root   55 Dec 21 15:36 commons-codec-1.9.jar -> /tmp/usercache/root/filecache/141/commons-codec-1.9.jar*
# -rw-r--r-- 1 root root   69 Dec 21 15:36 container_tokens
# -rwx------ 1 root root  623 Dec 21 15:36 default_container_executor.sh*
# -rwx------ 1 root root  568 Dec 21 15:36 default_container_executor_session.sh*
# lrwxrwxrwx 1 root root   55 Dec 21 15:36 kryo-shaded-4.0.2.jar -> /tmp/usercache/root/filecache/140/kryo-shaded-4.0.2.jar*
# -rwx------ 1 root root  12K Dec 21 15:36 launch_container.sh*
# $ command exited with code 0 (pid=2696)

# %%
# %%shell_command
#
# hostname -I
# Out:
# 172.18.0.7
# $ command exited with code 0 (pid=2699)

# %%
# %%shell_command
#
# bash -c 'echo foo && exit 42'
# Out:
# foo
# $ command exited with code 42 (pid=2700)

# %%
# %%local
#
# assert shell_output == 'foo\n'
# assert shell_returncode == 42

# %% [markdown]
# #### Sending local file

# %%
# %local !ls -lahF
# %send_path_to_spark -p magics.ipynb
# Out:
# total 68K
# drwxrwxr-x  5 app app 4.0K Dec 21 15:36 ./
# drwxrwxr-x 21 app app 4.0K Dec 21 15:13 ../
# drwxr-xr-x  2 app app 4.0K Jan 13  2025 .ipynb_checkpoints/
# -rw-rw-r--  1 app app  11K Dec 21 15:36 magics.ipynb
# drwxrwxr-x  3 app app 4.0K Jan  9  2025 sample-dir/
# drwxrwxr-x  2 app app 4.0K Dec 20 19:45 spark/
# -rw-rw-r--  1 app app  33K Dec 20 19:45 test-spark-another-version.ipynb
# Uploaded magics.ipynb to /tmp/usercache/root/appcache/application_1766330690133_0003/container_1766330690133_0003_01_000001/magics.ipynb

# %%
# %%shell_command
#
# ls -lahF | grep magics
# Out:
# -rw------- 1 root root  11K Dec 21 15:36 magics.ipynb
# $ command exited with code 0 (pid=2707)

# %%
# %%local
#
# assert 'magics.ipynb' in shell_output

# %% [markdown]
# #### Sending local directory

# %%
# %local !find sample-dir/
# Out:
# sample-dir/
# sample-dir/inner
# sample-dir/inner/bar.txt
# sample-dir/foo.txt

# %%
# %send_path_to_spark -p sample-dir/
# Out:
# Uploaded sample-dir to /tmp/usercache/root/appcache/application_1766330690133_0003/container_1766330690133_0003_01_000001/sample-dir

# %%
# %%shell_command
# pwd
# Out:
# /tmp/usercache/root/appcache/application_1766330690133_0003/container_1766330690133_0003_01_000001
# $ command exited with code 0 (pid=2712)

# %%
# %%shell_command
#
# find "$PWD/sample-dir"
# Out:
# /tmp/usercache/root/appcache/application_1766330690133_0003/container_1766330690133_0003_01_000001/sample-dir
# /tmp/usercache/root/appcache/application_1766330690133_0003/container_1766330690133_0003_01_000001/sample-dir/inner
# /tmp/usercache/root/appcache/application_1766330690133_0003/container_1766330690133_0003_01_000001/sample-dir/inner/bar.txt
# /tmp/usercache/root/appcache/application_1766330690133_0003/container_1766330690133_0003_01_000001/sample-dir/foo.txt
# $ command exited with code 0 (pid=2713)

# %%
# %%local
#
# assert 'sample-dir/' in shell_output

# %% [markdown]
# #### Following session logs

# %%
# %logs_follow -p 50
# Out:
# 25/12/21 15:36:03 INFO Client: Uploading resource file:/opt/hadoop-3.3.2/etc/livy/rsc-jars/livy-api-0.8.0-incubating.jar -> hdfs://namenode.localhost:9002/user/root/.sparkStaging/application_1766330690133_0003/livy-api-0.8.0-incubating.jar
# 25/12/21 15:36:03 INFO Client: Uploading resource file:/opt/hadoop-3.3.2/etc/livy/rsc-jars/netty-codec-memcache-4.1.86.Final.jar -> hdfs://namenode.localhost:9002/user/root/.sparkStaging/application_1766330690133_0003/netty-codec-memcache-4.1.86.Final.jar
# 25/12/21 15:36:03 INFO Client: Uploading resource file:/opt/hadoop-3.3.2/etc/livy/rsc-jars/netty-codec-socks-4.1.86.Final.jar -> hdfs://namenode.localhost:9002/user/root/.sparkStaging/application_1766330690133_0003/netty-codec-socks-4.1.86.Final.jar
# 25/12/21 15:36:04 INFO Client: Uploading resource file:/opt/hadoop-3.3.2/etc/livy/rsc-jars/netty-codec-haproxy-4.1.86.Final.jar -> hdfs://namenode.localhost:9002/user/root/.sparkStaging/application_1766330690133_0003/netty-codec-haproxy-4.1.86.Final.jar
# 25/12/21 15:36:04 INFO Client: Uploading resource file:/opt/hadoop-3.3.2/etc/livy/rsc-jars/netty-codec-dns-4.1.86.Final.jar -> hdfs://namenode.localhost:9002/user/root/.sparkStaging/application_1766330690133_0003/netty-codec-dns-4.1.86.Final.jar
# 25/12/21 15:36:05 INFO Client: Uploading resource file:/opt/hadoop-3.3.2/etc/livy/rsc-jars/netty-resolver-4.1.86.Final.jar -> hdfs://namenode.localhost:9002/user/root/.sparkStaging/application_1766330690133_0003/netty-resolver-4.1.86.Final.jar
# 25/12/21 15:36:05 INFO Client: Uploading resource file:/opt/hadoop-3.3.2/etc/livy/rsc-jars/netty-buffer-4.1.86.Final.jar -> hdfs://namenode.localhost:9002/user/root/.sparkStaging/application_1766330690133_0003/netty-buffer-4.1.86.Final.jar
# 25/12/21 15:36:06 INFO Client: Uploading resource file:/opt/hadoop-3.3.2/etc/livy/rsc-jars/netty-transport-native-unix-common-4.1.86.Final.jar -> hdfs://namenode.localhost:9002/user/root/.sparkStaging/application_1766330690133_0003/netty-transport-native-unix-common-4.1.86.Final.jar
# 25/12/21 15:36:06 INFO Client: Uploading resource file:/opt/hadoop-3.3.2/etc/livy/rsc-jars/netty-transport-4.1.86.Final.jar -> hdfs://namenode.localhost:9002/user/root/.sparkStaging/application_1766330690133_0003/netty-transport-4.1.86.Final.jar
# 25/12/21 15:36:06 INFO Client: Uploading resource file:/opt/hadoop-3.3.2/etc/livy/rsc-jars/netty-codec-http2-4.1.86.Final.jar -> hdfs://namenode.localhost:9002/user/root/.sparkStaging/application_1766330690133_0003/netty-codec-http2-4.1.86.Final.jar
# 25/12/21 15:36:07 INFO Client: Uploading resource file:/opt/hadoop-3.3.2/etc/livy/rsc-jars/netty-resolver-dns-native-macos-4.1.86.Final-osx-x86_64.jar -> hdfs://namenode.localhost:9002/user/root/.sparkStaging/application_1766330690133_0003/netty-resolver-dns-native-macos-4.1.86.Final-osx-x86_64.jar
# 25/12/21 15:36:07 INFO Client: Uploading resource file:/opt/hadoop-3.3.2/etc/livy/rsc-jars/netty-transport-native-epoll-4.1.86.Final-linux-aarch_64.jar -> hdfs://namenode.localhost:9002/user/root/.sparkStaging/application_1766330690133_0003/netty-transport-native-epoll-4.1.86.Final-linux-aarch_64.jar
# 25/12/21 15:36:08 INFO Client: Uploading resource file:/opt/hadoop-3.3.2/etc/livy/rsc-jars/netty-handler-4.1.86.Final.jar -> hdfs://namenode.localhost:9002/user/root/.sparkStaging/application_1766330690133_0003/netty-handler-4.1.86.Final.jar
# 25/12/21 15:36:08 INFO Client: Uploading resource file:/opt/hadoop-3.3.2/etc/livy/rsc-jars/netty-transport-native-epoll-4.1.86.Final-linux-x86_64.jar -> hdfs://namenode.localhost:9002/user/root/.sparkStaging/application_1766330690133_0003/netty-transport-native-epoll-4.1.86.Final-linux-x86_64.jar
# 25/12/21 15:36:08 INFO Client: Uploading resource file:/opt/hadoop-3.3.2/etc/livy/rsc-jars/netty-transport-udt-4.1.86.Final.jar -> hdfs://namenode.localhost:9002/user/root/.sparkStaging/application_1766330690133_0003/netty-transport-udt-4.1.86.Final.jar
# 25/12/21 15:36:09 INFO Client: Uploading resource file:/opt/hadoop-3.3.2/etc/livy/rsc-jars/netty-codec-mqtt-4.1.86.Final.jar -> hdfs://namenode.localhost:9002/user/root/.sparkStaging/application_1766330690133_0003/netty-codec-mqtt-4.1.86.Final.jar
# 25/12/21 15:36:09 INFO Client: Uploading resource file:/opt/hadoop-3.3.2/etc/livy/repl_2.12-jars/commons-codec-1.9.jar -> hdfs://namenode.localhost:9002/user/root/.sparkStaging/application_1766330690133_0003/commons-codec-1.9.jar
# 25/12/21 15:36:09 WARN Client: Same name resource file:///opt/hadoop-3.3.2/etc/livy/repl_2.12-jars/kryo-shaded-4.0.2.jar added multiple times to distributed cache
# 25/12/21 15:36:09 WARN Client: Same name resource file:///opt/hadoop-3.3.2/etc/livy/repl_2.12-jars/objenesis-2.5.1.jar added multiple times to distributed cache
# 25/12/21 15:36:09 WARN Client: Same name resource file:///opt/hadoop-3.3.2/etc/livy/repl_2.12-jars/minlog-1.3.0.jar added multiple times to distributed cache
# 25/12/21 15:36:09 INFO Client: Uploading resource file:/opt/hadoop-3.3.2/etc/livy/repl_2.12-jars/livy-repl_2.12-0.8.0-incubating.jar -> hdfs://namenode.localhost:9002/user/root/.sparkStaging/application_1766330690133_0003/livy-repl_2.12-0.8.0-incubating.jar
# 25/12/21 15:36:10 INFO Client: Uploading resource file:/opt/hadoop-3.3.2/etc/livy/repl_2.12-jars/livy-core_2.12-0.8.0-incubating.jar -> hdfs://namenode.localhost:9002/user/root/.sparkStaging/application_1766330690133_0003/livy-core_2.12-0.8.0-incubating.jar
# 25/12/21 15:36:10 INFO Client: Uploading resource file:/opt/hadoop-3.3.2/etc/spark/R/lib/sparkr.zip#sparkr -> hdfs://namenode.localhost:9002/user/root/.sparkStaging/application_1766330690133_0003/sparkr.zip
# 25/12/21 15:36:10 INFO Client: Uploading resource file:/opt/hadoop-3.3.2/etc/spark/python/lib/pyspark.zip -> hdfs://namenode.localhost:9002/user/root/.sparkStaging/application_1766330690133_0003/pyspark.zip
# 25/12/21 15:36:10 INFO Client: Uploading resource file:/opt/hadoop-3.3.2/etc/spark/python/lib/py4j-0.10.9.5-src.zip -> hdfs://namenode.localhost:9002/user/root/.sparkStaging/application_1766330690133_0003/py4j-0.10.9.5-src.zip
# 25/12/21 15:36:11 WARN Client: Same name resource file:///opt/hadoop-3.3.2/etc/spark/python/lib/pyspark.zip added multiple times to distributed cache
# 25/12/21 15:36:11 WARN Client: Same name resource file:///opt/hadoop-3.3.2/etc/spark/python/lib/py4j-0.10.9.5-src.zip added multiple times to distributed cache
# 25/12/21 15:36:11 INFO Client: Uploading resource file:/tmp/spark-8cb7aa08-7bb9-4397-ab46-06a779991980/__spark_conf__7596247700803728702.zip -> hdfs://namenode.localhost:9002/user/root/.sparkStaging/application_1766330690133_0003/__spark_conf__.zip
# 25/12/21 15:36:11 INFO SecurityManager: Changing view acls to: root
# 25/12/21 15:36:11 INFO SecurityManager: Changing modify acls to: root
# 25/12/21 15:36:11 INFO SecurityManager: Changing view acls groups to:
# 25/12/21 15:36:11 INFO SecurityManager: Changing modify acls groups to:
# 25/12/21 15:36:11 INFO SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users  with view permissions: Set(root); groups with view permissions: Set(); users  with modify permissions: Set(root); groups with modify permissions: Set()
# 25/12/21 15:36:11 INFO Client: Submitting application application_1766330690133_0003 to ResourceManager
# 25/12/21 15:36:11 INFO YarnClientImpl: Submitted application application_1766330690133_0003
# 25/12/21 15:36:11 INFO Client: Application report for application_1766330690133_0003 (state: ACCEPTED)
# 25/12/21 15:36:11 INFO Client:
# 	 client token: N/A
# 	 diagnostics: [Sun Dec 21 15:36:11 +0000 2025] Application is Activated, waiting for resources to be assigned for AM.  Details : AM Partition = <DEFAULT_PARTITION> ; Partition Resource = <memory:32768, vCores:16> ; Queue's Absolute capacity = 100.0 % ; Queue's Absolute used capacity = 0.0 % ; Queue's Absolute max capacity = 100.0 % ; Queue's capacity (absolute resource) = <memory:32768, vCores:16> ; Queue's used capacity (absolute resource) = <memory:0, vCores:0> ; Queue's max capacity (absolute resource) = <memory:32768, vCores:16> ;
# 	 ApplicationMaster host: N/A
# 	 ApplicationMaster RPC port: -1
# 	 queue: default
# 	 start time: 1766331371399
# 	 final status: UNDEFINED
# 	 tracking URL: http://resourcemanager.localhost:8088/proxy/application_1766330690133_0003/
# 	 user: root
# 25/12/21 15:36:11 INFO ShutdownHookManager: Shutdown hook called
# 25/12/21 15:36:11 INFO ShutdownHookManager: Deleting directory /tmp/spark-36ecac0b-fd6d-46b9-9817-b1c8692a7316
# 25/12/21 15:36:11 INFO ShutdownHookManager: Deleting directory /tmp/spark-8cb7aa08-7bb9-4397-ab46-06a779991980
#
# YARN Diagnostics:

# %%
# %logs_follow -p 50
# Out:
# No new logs

# %%
sc._gateway.jvm.java.lang.System.err.println('Hello World')
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
