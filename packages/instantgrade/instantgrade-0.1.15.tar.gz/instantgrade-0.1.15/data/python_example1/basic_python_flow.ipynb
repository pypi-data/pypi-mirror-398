# %% [markdown]
# # Basic Python Flow

# %%
# !pip install instantgrade

from instantgrade import Evaluator
# Out:
# Collecting instantgrade
#   Downloading instantgrade-0.1.0-py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: openpyxl>=3.0.0 in /Volumes/MacSSD/Areas/Github_Repositories/evaluator/.venv/lib/python3.13/site-packages (from instantgrade) (3.1.5)
# Requirement already satisfied: pandas>=1.0.0 in /Volumes/MacSSD/Areas/Github_Repositories/evaluator/.venv/lib/python3.13/site-packages (from instantgrade) (2.3.3)
# Requirement already satisfied: nbformat>=5.0.0 in /Volumes/MacSSD/Areas/Github_Repositories/evaluator/.venv/lib/python3.13/site-packages (from instantgrade) (5.10.4)
# Requirement already satisfied: nbclient>=0.5.0 in /Volumes/MacSSD/Areas/Github_Repositories/evaluator/.venv/lib/python3.13/site-packages (from instantgrade) (0.10.2)
# Collecting click>=7.0 (from instantgrade)
#   Downloading click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Volumes/MacSSD/Areas/Github_Repositories/evaluator/.venv/lib/python3.13/site-packages (from nbclient>=0.5.0->instantgrade) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Volumes/MacSSD/Areas/Github_Repositories/evaluator/.venv/lib/python3.13/site-packages (from nbclient>=0.5.0->instantgrade) (5.9.1)
# Requirement already satisfied: traitlets>=5.4 in /Volumes/MacSSD/Areas/Github_Repositories/evaluator/.venv/lib/python3.13/site-packages (from nbclient>=0.5.0->instantgrade) (5.14.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Volumes/MacSSD/Areas/Github_Repositories/evaluator/.venv/lib/python3.13/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->instantgrade) (2.9.0.post0)
# Requirement already satisfied: pyzmq>=23.0 in /Volumes/MacSSD/Areas/Github_Repositories/evaluator/.venv/lib/python3.13/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->instantgrade) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in /Volumes/MacSSD/Areas/Github_Repositories/evaluator/.venv/lib/python3.13/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->instantgrade) (6.5.2)
# Requirement already satisfied: platformdirs>=2.5 in /Volumes/MacSSD/Areas/Github_Repositories/evaluator/.venv/lib/python3.13/site-packages (from jupyter-core!=5.0.*,>=4.12->nbclient>=0.5.0->instantgrade) (4.5.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /Volumes/MacSSD/Areas/Github_Repositories/evaluator/.venv/lib/python3.13/site-packages (from nbformat>=5.0.0->instantgrade) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /Volumes/MacSSD/Areas/Github_Repositories/evaluator/.venv/lib/python3.13/site-packages (from nbformat>=5.0.0->instantgrade) (4.25.1)
# Requirement already satisfied: attrs>=22.2.0 in /Volumes/MacSSD/Areas/Github_Repositories/evaluator/.venv/lib/python3.13/site-packages (from jsonschema>=2.6->nbformat>=5.0.0->instantgrade) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Volumes/MacSSD/Areas/Github_Repositories/evaluator/.venv/lib/python3.13/site-packages (from jsonschema>=2.6->nbformat>=5.0.0->instantgrade) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Volumes/MacSSD/Areas/Github_Repositories/evaluator/.venv/lib/python3.13/site-packages (from jsonschema>=2.6->nbformat>=5.0.0->instantgrade) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /Volumes/MacSSD/Areas/Github_Repositories/evaluator/.venv/lib/python3.13/site-packages (from jsonschema>=2.6->nbformat>=5.0.0->instantgrade) (0.29.0)
# Requirement already satisfied: et-xmlfile in /Volumes/MacSSD/Areas/Github_Repositories/evaluator/.venv/lib/python3.13/site-packages (from openpyxl>=3.0.0->instantgrade) (2.0.0)
# Requirement already satisfied: numpy>=1.26.0 in /Volumes/MacSSD/Areas/Github_Repositories/evaluator/.venv/lib/python3.13/site-packages (from pandas>=1.0.0->instantgrade) (2.3.5)
# Requirement already satisfied: pytz>=2020.1 in /Volumes/MacSSD/Areas/Github_Repositories/evaluator/.venv/lib/python3.13/site-packages (from pandas>=1.0.0->instantgrade) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Volumes/MacSSD/Areas/Github_Repositories/evaluator/.venv/lib/python3.13/site-packages (from pandas>=1.0.0->instantgrade) (2025.2)
# Requirement already satisfied: six>=1.5 in /Volumes/MacSSD/Areas/Github_Repositories/evaluator/.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->nbclient>=0.5.0->instantgrade) (1.17.0)
# Downloading instantgrade-0.1.0-py3-none-any.whl (24 kB)
# Downloading click-8.3.1-py3-none-any.whl (108 kB)
# Installing collected packages: click, instantgrade
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [instantgrade]
# Successfully installed click-8.3.1 instantgrade-0.1.0

# %%
from instantgrade.utils.io_utils import generate_student_notebook

generate_student_notebook(
    instructor_path="./sample_solutions.ipynb",
    output_path="./submissions/student_notebook.ipynb"
)
# Out:
# ✅ Student notebook generated at: submissions/student_notebook.ipynb

# %%
eval = Evaluator("./sample_solutions.ipynb", "./submissions")
result = eval.run()

# %%
from instantgrade.utils.path_utils import filename_safe_timestamp_format

result.to_html(f"./report/report_{filename_safe_timestamp_format()}.html")
# Out:
# PosixPath('report/report_20251201_164554.html')

# %% [markdown]
# # EOF
