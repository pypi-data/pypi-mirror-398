# %% [markdown]
# # Student Assignment (Partial Incorrect Solutions)
# This file intentionally contains incorrect or incomplete implementations to test your evaluator.

# %%
name = "perfect but zero"
roll_number = "000 7 0000"

# %% [markdown]
# ## question_one (Incorrect Example)

# %%
def question_one(nums: list[int]) -> int:
    return sum(nums)  # incorrect: should sum unique values

# %% [markdown]
# ## question_two (Incorrect Example)

# %%
def question_two(xs: list) -> list:
    return xs  # incorrect: does not reverse

# %% [markdown]
# ## question_three (Incorrect Example)

# %%
def question_three(xs: list) -> dict:
    return {}  # incorrect: no counting

# %% [markdown]
# ## question_four (Incorrect Example)

# %%
def question_four(nested: list[list]) -> list:
    return nested  # incorrect: not flattened

# %% [markdown]
# ## question_five (Incorrect Example)

# %%
def question_five(d: dict) -> dict:
    inv = {}
    for k, v in d.items():
        inv.setdefault(v, []).append(k)
    return inv
