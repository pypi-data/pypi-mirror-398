# %%
import pfun_cma_model as pfuncma
from pfun_cma_model import read_sample_data
import pandas as pd

df: pd.DataFrame = pd.DataFrame(read_sample_data(convert2json=False))
df
# Out:
#       Unnamed: 0.1  Unnamed: 0   user_id               ts_utc  \
# 0                0           0  10130489  2021-01-18 09:48:09
# 1                1           1  10130489  2021-01-18 09:53:08
# 2                2           2  10130489  2021-01-18 09:58:08
# 3                3           3  10130489  2021-01-18 10:03:09
# 4                4           4  10130489  2021-01-18 10:08:08
# ...            ...         ...       ...                  ...
# 2874          2874        2874  10130489  2021-01-28 07:08:28
# 2875          2875        2875  10130489  2021-01-28 07:13:28
# 2876          2876        2876  10130489  2021-01-28 07:18:28
# 2877          2877        2877  10130489  2021-01-28 07:23:28
# 2878          2878        2878  10130489  2021-01-28 07:28:28
#
#                  ts_local  is_sg     sg  is_fl meal_tag  tag_bef_meal  \
# 0     2021-01-18 01:48:09      1  112.0      0      NaN          True
# 1     2021-01-18 01:53:08      1  102.0      0      NaN          True
# ...

# %% [markdown]
# # Plot the raw sample data

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
df_plt = df.loc[df.index <= df.index[10]]
df_plt.set_index('ts_local', inplace=True)
df_plt = df_plt.sort_index()
sns.lineplot(df_plt, x='ts_local', y='sg')
# Out:
# <Axes: xlabel='ts_local', ylabel='sg'>
