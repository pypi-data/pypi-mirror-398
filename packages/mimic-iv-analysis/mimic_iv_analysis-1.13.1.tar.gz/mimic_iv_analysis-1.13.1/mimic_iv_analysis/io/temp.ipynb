# %%
# %load_ext autoreload
# %autoreload 2

from mimic_iv_analysis.io import DataLoader
from mimic_iv_analysis.configurations.params import TableNames, ColumnNames

# %%
loader = DataLoader(apply_filtering=True)

df = loader.fetch_table(table_name=TableNames.MERGED)
# dfp = loader.fetch_table(table_name=TableNames.D_ICD_DIAGNOSES)

# %%
df = df.compute()
# dfp = dfp.compute()

# %%
df
# Out:
#         subject_id gender  anchor_age  anchor_year anchor_year_group dod  \
# 0         16855988      F          74         2184       2017 - 2019 NaT
# 1         16855988      F          74         2184       2017 - 2019 NaT
# 2         16855988      F          74         2184       2017 - 2019 NaT
# 3         16855988      F          74         2184       2017 - 2019 NaT
# 4         16855988      F          74         2184       2017 - 2019 NaT
# ...            ...    ...         ...          ...               ...  ..
# 885918    10969267      F          71         2162       2017 - 2019 NaT
# 885919    10969267      F          71         2162       2017 - 2019 NaT
# 885920    10969267      F          71         2162       2017 - 2019 NaT
# 885921    10969267      F          71         2162       2017 - 2019 NaT
# 885922    10969267      F          71         2162       2017 - 2019 NaT
#
#            admission_location     admission_type           admittime  \
# ...

# %%
df [ df.careunit == 'Medicine']
# Out:
#         subject_id gender  anchor_age  anchor_year anchor_year_group dod  \
# 7148      10212582      M          55         2171       2017 - 2019 NaT
# 7149      10212582      M          55         2171       2017 - 2019 NaT
# 7152      10212582      M          55         2171       2017 - 2019 NaT
# 7153      10212582      M          55         2171       2017 - 2019 NaT
# 7156      10212582      M          55         2171       2017 - 2019 NaT
# ...            ...    ...         ...          ...               ...  ..
# 877002    12129974      F          65         2188       2017 - 2019 NaT
# 877009    12129974      F          65         2188       2017 - 2019 NaT
# 877010    12129974      F          65         2188       2017 - 2019 NaT
# 877017    12129974      F          65         2188       2017 - 2019 NaT
# 877018    12129974      F          65         2188       2017 - 2019 NaT
#
#         admission_location     admission_type           admittime  \
# ...

# %%
dfp

# %%
df = dfc.merge(dfp, on=['icd_code', 'icd_version'], how='inner')
df

# %%
print('dfp', dfp.icd_code.nunique(), 'dfc', dfc.icd_code.nunique(), 'df', df.icd_code.nunique())
